# %% [markdown]
# ### BigCode python code dataset validation
#
# We find that in a subset of 10k filesin the **bigcode/python_safe_license**, only 0.24% of the files don't compile and have syntax errors

# %%
from datasets import load_dataset

# %%
data = load_dataset('bigcode/python_safe_license', streaming=True, split="train", use_auth_token=True, ignore_verifications=True)
# Out:
# Using custom data configuration bigcode--python_safe_license-05b1c2b44aa5d114

# %%
import tempfile
import subprocess
from tqdm import tqdm

def compile_python_code(sample):
    string = sample["content"]
    tmp = tempfile.NamedTemporaryFile()
    with open(tmp.name, "w") as f:
        f.write(string)
    py_command = "python{v} -m py_compile " + tmp.name
    
    try:
        subprocess.check_call(py_command.format(v=3).split())
        python3_works = True
    except subprocess.CalledProcessError:
        python3_works = False

    try:
        subprocess.check_call(py_command.format(v=2).split())
        python2_works = True
    except subprocess.CalledProcessError:
        python2_works = False

    return python2_works or python3_works

# %%
subset = list(data.shuffle(seed=42).take(10_000))

# %%
python_checks = []
for i in tqdm(range(len(subset))):
    python_checks.append(compile_python_code(subset[i]))

# %%
print(f"number of valid python files in the first 10k: {sum(python_checks)}")
print(f"percentage of non valid files: {(len(python_checks) - sum(python_checks)) * 100 / len(python_checks)}%")
# Out:
# number of valid python files in the first 10k: 9976
# percentage of non valid files: 0.24%

# %% [markdown]
# ### Examples of files that don't compile

# %%
# show which files weren't valid
for i, e in enumerate(python_checks):
    if not e:
        print(i)
# Out:
# 705
# 1412
# 1490
# 1584
# 1962
# 2378
# 2431
# 2555
# 2581
# 2659
# 3044
# 3060
# 3069
# 3711
# 3837
# 4629
# 6101
# 6901
# 6917
# 6920
# 7794
# 8084
# 8560
# 9495

# %%
compile_python_code(subset[705])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5r13si_2", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5r13si_2", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
# False

# %%
compile_python_code(subset[1412])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgk6cray7", line 11
#     from tensorflow.keras.metrics import AUC, MeanSquaredError, RootMeanSquaredError,
#                                                                                      ^
# SyntaxError: trailing comma not allowed without surrounding parentheses
# Sorry: IndentationError: unexpected indent (tmpgk6cray7, line 12)
# False

# %%
compile_python_code(subset[1490])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2zt_z_cm", line 167
#     elif:
#         ^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2zt_z_cm", line 167
#     elif:
#         ^
# SyntaxError: invalid syntax
# False

# %% [markdown]
# ## Codeparrot

# %%
data = load_dataset('codeparrot/codeparrot-clean-train', streaming=True, split="train", use_auth_token=True, ignore_verifications=True)
# Out:
# Using custom data configuration codeparrot--codeparrot-clean-train-22d8adb9ce08010a

# %%
subset = list(data.shuffle(seed=42).take(10_000))

# %%
python_checks = []
for i in tqdm(range(len(subset))):
    python_checks.append(compile_python_code(subset[i]))
# Out:
#   0%|          | 5/10000 [00:00<20:42,  8.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjjmebq72", line 91
#     print [acronym,name,photoUrl]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 9/10000 [00:01<20:56,  7.95it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqq4vnl99", line 16
#     raise ValidationError("Not a valid version.") from e
#                                                      ^
# SyntaxError: invalid syntax
#
#   0%|          | 11/10000 [00:01<20:48,  8.00it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp08jb48nv", line 43
#     except Exception, e:
#            ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   0%|          | 16/10000 [00:02<19:39,  8.46it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:141: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'imul'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:191: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'a>>'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:195: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'a>>'(arg2, arg3 & i32(0x1F))
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:258: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = '>>>'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:263: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fadd'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:268: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fsub'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:273: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fdiv'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:278: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fmul'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:336: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fcomp_lt'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:340: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fcomp_eq'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:344: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'fcomp_le'(arg2, arg3)
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpimhsisx4:361: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   arg1 = 'flt_d_w'(arg2)
#   0%|          | 20/10000 [00:02<19:42,  8.44it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqyqls7_2", line 42
#     print arglist
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 21/10000 [00:02<19:43,  8.44it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_veb6ms0:123: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert response.data['count'] is 0
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_veb6ms0:133: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert response.data['count'] is 0
#   0%|          | 25/10000 [00:03<19:38,  8.47it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphiucjvoo", line 8
#     print atautils.atautils.autokcal
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 27/10000 [00:03<19:47,  8.40it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv1roqv13", line 99
#     				print e
#     				^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 29/10000 [00:03<20:01,  8.30it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgwlt_cyz", line 110
#     self.assertEquals([c.connected for c in c1, c2, c3], [1, 1, 1])
#                                               ^
# SyntaxError: invalid syntax
#   0%|          | 33/10000 [00:04<19:47,  8.39it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0y42vf7t", line 263
#     self.crc32=zlib.crc32(data, self.crc32) & 0xffffffffL
#                                                        ^
# SyntaxError: invalid hexadecimal literal
#   0%|          | 36/10000 [00:04<21:06,  7.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnj6u654c", line 58
#     print cmd
#     ^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 39/10000 [00:04<21:11,  7.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7zjwiuvp", line 183
#     print 'Unusual case ' + repr(e)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 40/10000 [00:04<20:53,  7.95it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprbibr7hl", line 86
#     exec='"{}" %f'.format(os.path.join(self.install_path, "Stencyl")),
#        ^
# SyntaxError: invalid syntax
#
#   0%|          | 41/10000 [00:05<20:57,  7.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpr3go95n2", line 33
#     print(f'\n## [{comment.replace("v", "")}] - {date}')
#                                                       ^
# SyntaxError: invalid syntax
#
#   0%|          | 42/10000 [00:05<20:41,  8.02it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfmpruwyw", line 61
#     print self.features
#     ^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   0%|          | 43/10000 [00:05<21:36,  7.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptbe5dw5n", line 23
#     print 'Missing dependency:'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 51/10000 [00:06<20:21,  8.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpctsw85tb", line 10
#     except OSError, e:
#            ^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   1%|          | 56/10000 [00:06<20:08,  8.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpavpu1ago", line 80
#     label = f"{form.form_title} 1: {field.label}"
#                                                 ^
# SyntaxError: invalid syntax
#
#   1%|          | 59/10000 [00:07<19:23,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpzb86j8zl", line 39
#     print 'trying to get IVY'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 62/10000 [00:07<19:28,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8emygh5y", line 482
#     print couchpotato
#     ^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 63/10000 [00:07<19:49,  8.35it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2qg8cfa0", line 43
#     except urllib2.HTTPError, e:
#            ^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   1%|          | 68/10000 [00:08<20:09,  8.21it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpk05w5i7m", line 411
#     except Exception, e:
#            ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   1%|          | 73/10000 [00:09<20:59,  7.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpe51p8290", line 52
#     except Exception, e:
#            ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   1%|          | 78/10000 [00:09<20:58,  7.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpre18ujgh", line 18
#     print scenes
#     ^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 80/10000 [00:09<20:27,  8.08it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpi6_d2a2s", line 161
#     (project_id, dataset_id)) from e
#                                  ^
# SyntaxError: invalid syntax
#
#   1%|          | 83/10000 [00:10<20:06,  8.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcwtv59bm", line 6
#     def add_objects(scene: QGraphicsScene, n=1000):
#                          ^
# SyntaxError: invalid syntax
#
#   1%|          | 86/10000 [00:10<19:59,  8.26it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1bkn388r", line 13
#     print "ready"
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 88/10000 [00:10<25:03,  6.59it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8lu7f2t7:56: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if run_ddt is not 0:
#   1%|          | 91/10000 [00:11<22:02,  7.49it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpd5bx53an", line 29
#     print "Trying to fetch Google Map Maker but failed"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 98/10000 [00:12<19:28,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0azcryc2", line 284
#     self.assertTrue(int(tarinfo.mtime) == 07606136617,
#                                           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   1%|          | 103/10000 [00:12<20:09,  8.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpoxr7w5r3", line 89
#     prev_period: Optional[datetime],
#                ^
# SyntaxError: invalid syntax
#
#   1%|          | 107/10000 [00:13<20:39,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpi4f29der", line 421
#     os.chmod(directory, 02775)
#                         ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   1%|          | 113/10000 [00:13<19:51,  8.29it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv2_yu4qf", line 82
#     raise AttributeError, fn + ' is not a search function in search.py.'
#                         ^
# SyntaxError: invalid syntax
#   1%|          | 119/10000 [00:14<19:29,  8.45it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpog_jsofq", line 311
#     print "Unknown: "+n.nodeName
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|          | 123/10000 [00:15<19:31,  8.43it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8eqf0ngh", line 81
#     print h.is_email('konker@gmail.com')
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|▏         | 126/10000 [00:15<21:06,  7.79it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphd5tjhz7", line 128
#     def automations_with_entity(hass: HomeAssistant, entity_id: str) -> List[str]:
#                                     ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 127/10000 [00:15<20:57,  7.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptcyfxa1x", line 12
#     print set(G.nodes()) - set(H.nodes())
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|▏         | 130/10000 [00:16<20:27,  8.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8530z9hr", line 78
#     print sample_id+'\t'+str(new_block_id)+'\t'+out_bin
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|▏         | 133/10000 [00:16<20:23,  8.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjzkghk3p", line 221
#     print 'Firing up Index Server.'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   1%|▏         | 146/10000 [00:17<19:48,  8.29it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp26trppsa", line 34
#     async def get_page_body(ctx: HTTPRequestContext, url: str, cache_time=300, cache_404=False) -> str:
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 151/10000 [00:18<19:50,  8.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpb1o28sdm", line 142
#     print "Error: Service template %s properties not found"\
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 161/10000 [00:19<22:36,  7.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpggu09csz", line 61
#     			print '!! Missing argument'
#     			^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 162/10000 [00:20<21:50,  7.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqugo1nt8", line 138
#     self.txokiñ()
#               ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 166/10000 [00:20<20:19,  8.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpct8alke2", line 25
#     print "Deploying datablox to %s" % dh
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 172/10000 [00:21<19:38,  8.34it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnfn3tst1", line 45
#     print "[QUIT]"
#     ^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 174/10000 [00:21<19:00,  8.61it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_fbe8_38", line 61
#     [print('{0}{1}'.format(indent, file)) for file in os.listdir()]
#          ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 175/10000 [00:21<19:05,  8.58it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkwsjkfa8", line 43
#     print prim(g)
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 177/10000 [00:21<19:19,  8.47it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp28j0kuak", line 54
#     if len(sys.argv)<> 5:
#                     ^^
# SyntaxError: invalid syntax
#   2%|▏         | 181/10000 [00:22<19:20,  8.46it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp43yetol5", line 157
#     except Exception, err:
#            ^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   2%|▏         | 183/10000 [00:22<20:05,  8.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpufvdwvjl", line 33
#     print "Downloaded: %s" % fn
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 186/10000 [00:22<19:02,  8.59it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbsf9_utn", line 61
#     os.chmod(f, 0755)
#                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   2%|▏         | 187/10000 [00:22<18:57,  8.63it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmplty1rbkc", line 254
#     today = date(2012, 12, 02)
#                            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   2%|▏         | 190/10000 [00:23<19:19,  8.46it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpo1ar45th", line 29
#     async def test_get_nonexistant_feed(mock_http_client):
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 194/10000 [00:23<19:38,  8.32it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpj9pc1wzu", line 260
#     except mpd.InvalidNotenameException, e:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   2%|▏         | 195/10000 [00:23<20:17,  8.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwjybqwvr", line 40
#     print "Precompute S^T and X^TX (if necessary)"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 196/10000 [00:24<20:12,  8.09it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpzj7gydly", line 44
#     except Fault, exception:
#            ^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   2%|▏         | 197/10000 [00:24<20:42,  7.89it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpidby5nkd", line 39
#     print 'Fetching test set---DONE!'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 202/10000 [00:24<18:53,  8.64it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbat49r4h", line 127
#     print sample
#     ^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 204/10000 [00:25<18:55,  8.63it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1cwgk4y4", line 58
#     print 'NOTE: please double check your new HTML/LaTeX processing settings in BibIndex Admin Interface.'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 210/10000 [00:25<19:11,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6jey6rz2", line 68
#     print "No formation points defined in section " + sectionname
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 219/10000 [00:26<18:50,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptnu1042a", line 9
#     FORMAT: str = 'json'
#           ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 226/10000 [00:27<18:48,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8lof3e8_", line 76
#     print "Unknown metric"
#     ^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 228/10000 [00:27<19:13,  8.47it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppon_a5g3", line 37
#     print minified
#     ^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 232/10000 [00:28<18:37,  8.74it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphyfextn2", line 54
#     print "Line %d doesn't have five values. This is an error."
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 234/10000 [00:28<18:31,  8.79it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8qelu0l6", line 10
#     print "importing wordlist"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 242/10000 [00:29<18:49,  8.64it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpxsjlytkb", line 19
#     print "Sity_name = ", Sity_name
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 243/10000 [00:29<18:27,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpur_l8fs4", line 29
#     print "file %s" % tfn
#     ^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 245/10000 [00:29<18:13,  8.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphlhvkugp", line 93
#     print "Please make sure django-graphviz app folder 'graphviz' is installed, the GRAPHVIZ_DOT_CMD contains the right path to graphviz, then run syncdb."
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 251/10000 [00:30<18:23,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpolm5fo14", line 174
#     print "Not your lucky day!"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 256/10000 [00:31<18:32,  8.76it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppyyaayr6", line 18
#     def __init__(self, logic: {'policy', 'value'}, verbose=False):
#                             ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 257/10000 [00:31<18:24,  8.82it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp40vbgnf6", line 16
#     print 'Using CONFIG_PATH %s' % CONFIG_PATH
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 258/10000 [00:31<18:16,  8.89it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfksijyqd", line 57
#     class Structure(metaclass = StructMeta):
#                               ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 264/10000 [00:31<18:19,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp54cbop1j", line 154
#     print "Usage:"
#     ^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 271/10000 [00:32<17:59,  9.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpi1g1iix6", line 33
#     						print "We are now in %s" % dir
#     						^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 272/10000 [00:32<17:55,  9.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp11barvba", line 151
#     async_result = formset.enqueue(f"extfile_formset.{dg.pk}")
#                                                             ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 278/10000 [00:33<18:39,  8.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppjvr8k7s", line 369
#     print("\n Checking arguments \r", end="")
#                                          ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 286/10000 [00:34<18:29,  8.76it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpghwl6erd", line 34
#     print "Signature(Calculated): %s" % signature
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 287/10000 [00:34<18:16,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7tko4ya1", line 12
#     	print "\n\t   d3hydr8[at]gmail[dot]com GoogEmail v1.0"
#     	^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 288/10000 [00:34<18:08,  8.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcctcjbj2", line 23
#     φ1, φ2 = map(radians, [x.lat, y.lat])
#     ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 292/10000 [00:35<18:13,  8.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpa59ugm1n", line 38
#     print "No user files, please put the files in current directory."
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 295/10000 [00:35<18:09,  8.91it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnys9afnf", line 20
#     async def __aenter__(self):
#             ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 302/10000 [00:36<19:27,  8.30it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwehqwbwg", line 31
#     print "Distribution: {0}".format(family)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 303/10000 [00:36<20:46,  7.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpuc33o_3r", line 21
#     os.umask(022)
#              ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   3%|▎         | 304/10000 [00:36<20:14,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp482_nvcm", line 4
#     raise ImportError, "OpenGL must be installed to use these functionalities"
#                      ^
# SyntaxError: invalid syntax
#   3%|▎         | 308/10000 [00:36<19:34,  8.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpi37r20li", line 53
#     		print self.commentsStr + ": Setting Logging flag!"
#     		^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 314/10000 [00:37<19:01,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpac2m7525", line 9
#     print obj.name
#     ^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 322/10000 [00:38<18:53,  8.54it/s]Sorry: TabError: inconsistent use of tabs and spaces in indentation (tmp301vcxcf, line 11)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwhrv9re1", line 14
#     from homeassistant.util.async import run_coroutine_threadsafe
#                             ^^^^^
# SyntaxError: invalid syntax
#   3%|▎         | 325/10000 [00:38<18:22,  8.77it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5fgnz9g3", line 36
#     print "failed to find connection"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 326/10000 [00:39<18:20,  8.79it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp11n_n1bs", line 27
#     print "requesting..."
#     ^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 332/10000 [00:39<17:57,  8.97it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4kcyzx_3", line 47
#     print "Information about mesh:"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 337/10000 [00:40<17:53,  9.00it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpvvlc09ru", line 42
#     qval: int = 2,
#         ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 343/10000 [00:40<18:01,  8.93it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqxpamgk7", line 205
#     mode=0600,
#          ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   3%|▎         | 345/10000 [00:41<18:09,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptjll9slr", line 70
#     except redis.exceptions.ConnectionError, e:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   3%|▎         | 348/10000 [00:41<18:06,  8.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpzbl6p302", line 37
#     print 'Using URL: %s' % temp
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▎         | 359/10000 [00:42<18:08,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnotul04w", line 237
#     		except StandardError, e:
#     		       ^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   4%|▎         | 365/10000 [00:43<17:58,  8.93it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp82ub36cg", line 56
#     print "MJD Forecast Measured"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▎         | 366/10000 [00:43<18:01,  8.90it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4vwkh765", line 40
#     print(wrd_to_phn, words, phones, file=sys.stderr)
#                                          ^
# SyntaxError: invalid syntax
#
#   4%|▎         | 368/10000 [00:43<18:08,  8.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphm_4bzza", line 65
#     except Exception,e:
#            ^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   4%|▍         | 381/10000 [00:45<18:22,  8.72it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7u1_4_zn", line 63
#     print path2script
#     ^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 400/10000 [00:47<19:11,  8.34it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5o40p6ru", line 92
#     except Exception, e:
#            ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   4%|▍         | 402/10000 [00:47<18:51,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwhvz7y2l", line 26
#     print "\n\n"
#     ^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 403/10000 [00:47<18:39,  8.57it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbddsg1g3", line 51
#     print """
#     ^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 406/10000 [00:48<18:49,  8.49it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpq17sqo5n", line 31
#     print "Distance:",Distance,"mm"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 409/10000 [00:48<18:42,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjy87b5vu", line 543
#     print sunrise_utc, sunset_utc
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 418/10000 [00:49<19:34,  8.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpql6merf9", line 26
#     	print current_user.username
#     	^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 428/10000 [00:50<19:48,  8.06it/s]Sorry: TabError: inconsistent use of tabs and spaces in indentation (tmp1ab9lsd6, line 17)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5l_c0lcw", line 21
#     def main_title(object: mediaupdate.mediaUpdateType, new_value: str = None) -> Union[str, mediaupdate.titleUpdateType, None]:
#                          ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 430/10000 [00:51<19:03,  8.37it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphr91d2z5", line 54
#     'Description'     :   'Comma separated list of usernames to use for relay attacks. Accepts both username and domain\username format.',
#                                                                                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 92-93: truncated \uXXXX escape
#   4%|▍         | 432/10000 [00:51<18:45,  8.50it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnj4luhxd", line 6
#     raise Exception, 'Must register module with an application to use this method.'
#                    ^
# SyntaxError: invalid syntax
#   4%|▍         | 433/10000 [00:51<18:40,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpouowsf_d", line 31
#     print openOrSenior([[45, 12],[55,21],[19, -2],[104, 20]])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 438/10000 [00:51<18:53,  8.43it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfcylcmbi", line 35
#     print 'connected'
#     ^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▍         | 439/10000 [00:52<18:52,  8.45it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3c4bkfl4", line 32
#     circuit: 'cirq.Circuit',
#            ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 443/10000 [00:52<18:37,  8.55it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpg4dij4bk", line 257
#     except subp.CalledProcessError, exception:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   4%|▍         | 449/10000 [00:53<18:59,  8.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2_8g9hpz", line 49
#     print math.pi
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 452/10000 [00:53<18:59,  8.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpagpxxgx9", line 117
#     print keywords
#     ^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 454/10000 [00:53<19:48,  8.03it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbnnkxk7d:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response.status_code is 200:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbnnkxk7d:102: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response.status_code is 200:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbnnkxk7d:125: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if not response.status_code is 200:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbnnkxk7d:183: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response.status_code is 200:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbnnkxk7d:207: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if req.status_code is 200:
#   5%|▍         | 457/10000 [00:54<19:38,  8.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcwn1yl52", line 14
#     def PiRabi(controlQ: qreg, targetQ: qreg, lengths, riseFall=40e-9, amp=1, phase=0, calRepeats=2):
#                        ^
# SyntaxError: invalid syntax
#
#   5%|▍         | 462/10000 [00:54<18:36,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3od9vmxg", line 267
#     return self.retrieveFileFromOffset(service_name, path, file_obj, 0L, -1L, timeout)
#                                                                      ^
# SyntaxError: invalid decimal literal
#   5%|▍         | 463/10000 [00:54<18:38,  8.53it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_ww51bzy", line 37
#     print '%s秒后系统退出!!!' % s
#     ^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 464/10000 [00:55<18:18,  8.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpc9jd7lm4", line 50
#     print 'list of images: ', images
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 465/10000 [00:55<18:07,  8.76it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpo1zcontr", line 63
#     print "params:", params
#     ^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 466/10000 [00:55<18:05,  8.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp282pijuz", line 46
#     print 'beging boreHole sim'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 468/10000 [00:55<18:12,  8.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpf871pllp", line 147
#     except RuntimeError, e:
#            ^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   5%|▍         | 469/10000 [00:55<18:40,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpm1l2t5h7", line 18
#     print err
#     ^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 470/10000 [00:55<18:23,  8.63it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprjifkuwd", line 38
#     class ConfigFlow(config_entries.ConfigFlow, domain=DOMAIN):
#                                                       ^
# SyntaxError: invalid syntax
#
#   5%|▍         | 472/10000 [00:55<17:56,  8.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpvx8_6sc0", line 75
#     print("nothing to do!", file=sys.stderr)
#                                 ^
# SyntaxError: invalid syntax
#
#   5%|▍         | 473/10000 [00:56<17:51,  8.89it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpq8z7n5o1", line 161
#     		print "Next char: "
#     		^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▍         | 474/10000 [00:56<17:58,  8.84it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpf_8o5lky", line 68
#     os.chmod(conf.watch_directory,0777)
#                                   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#   5%|▍         | 496/10000 [00:58<17:53,  8.86it/s]Sorry: TabError: inconsistent use of tabs and spaces in indentation (tmpj33msgy9, line 41)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpk5slztpy", line 45
#     def __init__(self, client, async=False,
#                                ^^^^^
# SyntaxError: invalid syntax
#   5%|▌         | 503/10000 [00:59<18:55,  8.36it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpph7ghmia", line 106
#     def create_influx_url(conf: dict) -> dict:
#                               ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 511/10000 [01:00<17:36,  8.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpc4m2c4xc", line 19
#     print org
#     ^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 512/10000 [01:00<17:32,  9.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnl6qsvlb", line 65
#     print "\t".join(map(str, [
#     ^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 520/10000 [01:01<17:47,  8.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmps2n_p424", line 94
#     data = {**data, **fields}
#              ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 522/10000 [01:01<17:55,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1a8rym44", line 48
#     raise AssertionError, "not reached!"
#                         ^
# SyntaxError: invalid syntax
#   5%|▌         | 527/10000 [01:02<17:56,  8.80it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpif22vvwu", line 42
#     print "Migrating Account %s" % account.username
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 534/10000 [01:03<17:38,  8.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1l44gbb9", line 20
#     async def _check_request_resolves(request: Request,
#             ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 536/10000 [01:03<17:26,  9.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjh6ac5_1", line 104
#     		print 'Warning: unable to open video source: 0'
#     		^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 538/10000 [01:03<17:33,  8.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprgmcz3zx", line 32
#     async def update():
#             ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 540/10000 [01:03<17:57,  8.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptq2oo6at", line 47
#     raise IOError, "Illegal argument"
#                  ^
# SyntaxError: invalid syntax
#   5%|▌         | 541/10000 [01:03<18:33,  8.49it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbzemfm8k", line 51
#     def __init__(self, *, questions=None, answer: str=None, score: float=None, id: int=None, source: str=None, metadata=None, context=None, answer_span=None, **kwargs) -> None:
#                         ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 542/10000 [01:04<18:40,  8.44it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpw_a22i0z", line 54
#     print 'exactly platform, chromium_os flag and input file must be specified.'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 547/10000 [01:04<17:56,  8.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2_72ws1k", line 996
#     if stock_picking_obj.browse(cr, uid, order.picking_id.id, context=context).state <> 'cancel':
#                                                                                      ^^
# SyntaxError: invalid syntax
#   6%|▌         | 562/10000 [01:06<17:26,  9.02it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpxxhtotuq", line 60
#     print os.path.join(dirpath, fname), 'CSS fixed'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 564/10000 [01:06<17:46,  8.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfrkm6kyr", line 45
#     username: str,
#             ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 567/10000 [01:06<18:04,  8.70it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp12aolj1t", line 36
#     except NoSuchElementException, e: return False
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   6%|▌         | 569/10000 [01:07<17:50,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6lprae74", line 33
#     print "[%s] %s" % (time.strftime("%H:%M.%S"),text)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 572/10000 [01:07<18:00,  8.72it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpll1s8zo8", line 37
#     print message
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 574/10000 [01:07<18:01,  8.72it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpc93t68_g", line 121
#     	print 'test save objective_array'
#     	^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 580/10000 [01:08<17:49,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmph507c3os", line 16
#     except ImportError,e:
#            ^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   6%|▌         | 589/10000 [01:09<18:14,  8.60it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptiprrd4v", line 15
#     print "Got a class: {0}".format(self)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 597/10000 [01:10<17:47,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8time915", line 13
#     <<<<<<< HEAD
#     ^^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8time915", line 13
#     <<<<<<< HEAD
#      ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 599/10000 [01:10<17:53,  8.76it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpxhvhy7it", line 12
#     def __init__(self, cost: float, amount: float) -> None:
#                            ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 600/10000 [01:10<19:59,  7.84it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpuidf9t73", line 33
#     start, this_year, owner), file=out_file)
#                                   ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 602/10000 [01:10<19:12,  8.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3ig5q1ov", line 216
#     self.logger.debug(f"Expected number of matches:  "
#                                                      ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 619/10000 [01:12<19:29,  8.02it/s]Sorry: IndentationError: unexpected indent (tmpb9pxg8x7, line 298)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpb9pxg8x7", line 34
#     yield from self.send(json.dumps([msg]))
#              ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 630/10000 [01:14<18:59,  8.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7s1cw6s7", line 78
#     print MU
#     ^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▋         | 634/10000 [01:14<18:55,  8.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqigv3jg9", line 404
#     except ValidationError, e:
#            ^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   6%|▋         | 637/10000 [01:15<19:07,  8.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjjyf8td8", line 18
#     raise template.TemplateSyntaxError, "%r tag requires three arguments" % token.contents.split()[0]
#                                       ^
# SyntaxError: invalid syntax
#   6%|▋         | 641/10000 [01:15<19:38,  7.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqfpbiw9f", line 43
#     print solution.maximalRectangle(["0"])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▋         | 645/10000 [01:16<18:17,  8.53it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9ma8z4xk", line 36
#     sources: Tuple[str, ...]
#            ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 649/10000 [01:16<17:40,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdbieimoz", line 66
#     print recall;
#     ^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   7%|▋         | 656/10000 [01:17<18:14,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcdy8fbkj", line 870
#     raise SyntaxError, "Must specify a stream or filename or content"
#                      ^
# SyntaxError: invalid syntax
#   7%|▋         | 661/10000 [01:17<17:33,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpejucext7", line 61
#     			except calc.Error, e:
#     			       ^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   7%|▋         | 664/10000 [01:18<17:39,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpz4f8viy8", line 98
#     def _py_decrypt(self, v, key, n=32, delta=DELTA, mask=0xffffffffL):
#                                                                    ^
# SyntaxError: invalid hexadecimal literal
#   7%|▋         | 667/10000 [01:18<18:03,  8.61it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmplhmcr5k8", line 282
#     except (IOError, os.error), reason:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   7%|▋         | 670/10000 [01:19<18:27,  8.42it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpyw3i2rkq", line 74
#     print Xml2Json('<doc><tag><subtag>data</subtag><t>data1</t><t>data2</t></tag></doc>').result
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   7%|▋         | 672/10000 [01:19<17:51,  8.70it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6fkbwsaj", line 31
#     		print str(x) + '  ' +  " ".join( list( map( lambda x: color(x), b[x] ) ) )
#     		^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   7%|▋         | 673/10000 [01:19<17:53,  8.69it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpr8s400qj", line 84
#     except dbapi.DatabaseError, exc:
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     print json.dumps(response.json(), indent=4, sort_keys = True)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9803/10000 [18:54<00:23,  8.44it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphvnerorh", line 44
#     print "Max baseline: ", np.sqrt(((xc[nt_3-1]-xc[2*nt_3-1])**2 + (yc[nt_3-1]-yc[2*nt_3-1])**2))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9805/10000 [18:55<00:22,  8.65it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp47rc6zjx", line 9
#     async def gather_dict(d):
#             ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9808/10000 [18:55<00:21,  8.90it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfa7ivjkx", line 150
#     raise Exception, 'no path, not deleted'
#                    ^
# SyntaxError: invalid syntax
#  98%|█████████▊| 9812/10000 [18:55<00:21,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4962uag6", line 129
#     if debug: print "trace", expr, "/", path
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9819/10000 [18:56<00:20,  9.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv8desi_p", line 60
#     print details
#     ^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9823/10000 [18:57<00:20,  8.70it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwqzjv93v", line 71
#     print left, top, width, height
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9824/10000 [18:57<00:20,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp14yhg2hb", line 35
#     print status.coordinates
#     ^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9825/10000 [18:57<00:19,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpyc0lwc7g", line 104
#     print "the number of unique assets are " + str(len(s))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9837/10000 [18:58<00:18,  8.91it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp69a4tyei", line 54
#     policy: FeedForwardPolicy,
#           ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9841/10000 [18:59<00:18,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpulqdcd08", line 138
#     raise ValueError, "ZPT attempted to fetch %s" % key
#                     ^
# SyntaxError: invalid syntax
#  98%|█████████▊| 9843/10000 [18:59<00:17,  8.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpr7baxohn", line 31
#     		print str(f3)
#     		^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9850/10000 [19:00<00:16,  8.99it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8vygpaiq", line 22
#     def generate_and_validate(integrations: Dict[str, Integration]):
#                                           ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9854/10000 [19:00<00:16,  9.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8tze82dw", line 65
#     print '\nNumber of results found: %s' % response['totalResultSetSize']
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9861/10000 [19:01<00:15,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcj6vz20l", line 65
#     print "Incorrect sequence"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9863/10000 [19:01<00:15,  9.02it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwb82zpog", line 54
#     print 'Lineage ' + taxonomyStr + ' contains ' + str(len(genomeIds)) + ' genomes.'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9868/10000 [19:02<00:14,  8.97it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp725_cma8", line 11
#     	print x.sensors
#     	^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9870/10000 [19:02<00:14,  9.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpys46nncr", line 48
#     print "#pc <=0, do not remove pc"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9874/10000 [19:02<00:14,  8.91it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7vo0e7au", line 1015
#     except Exception, e:
#            ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#  99%|█████████▉| 9879/10000 [19:03<00:14,  8.58it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpo78bd31n", line 254
#     except TypeError, ValueError:
#            ^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#  99%|█████████▉| 9883/10000 [19:03<00:13,  8.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8ztead7v", line 117
#     def ask_for_filename(suggested_filename, win_id, *, parent=None,
#                                                       ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9884/10000 [19:04<00:13,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3m1oyw3c", line 129
#     print "Cannot open", xds_file
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▉| 9885/10000 [19:04<00:12,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp352792al", line 26
#     		except Exception, e:
#     		       ^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#  99%|█████████▉| 9886/10000 [19:04<00:13,  8.47it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5h50ndus", line 35
#     async def issue_credential():
#             ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9891/10000 [19:04<00:12,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppgv0fpx3", line 170
#     f" table (hdu={first(tables)})",
#     ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9892/10000 [19:04<00:12,  8.90it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkjlv3z6t", line 90
#     return ...
#            ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9893/10000 [19:05<00:12,  8.57it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpj4yeq0te", line 107
#     print "Removed %s from default parameters." % str(name)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▉| 9894/10000 [19:05<00:12,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfsxbiynq", line 22
#     except ImportError, exc:
#            ^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#  99%|█████████▉| 9899/10000 [19:05<00:11,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_9rcq0op", line 88
#     log(test_timer, test_name="test_timer_repeating_dst_skip", base_time=calendar.timegm((2007, 03, 20, 0, 0, 0)), timer_start=3600, repeat=0x7f, sim_length=86400 * 7)
#                                                                                                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
#  99%|█████████▉| 9904/10000 [19:06<00:10,  9.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3r485zqf", line 217
#     def open(self, mode='r', *args, pwd=None, **kwargs):
#                                       ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9908/10000 [19:06<00:10,  8.75it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if add is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:44: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if add is 1:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:50: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if add is 2:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:105: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:119: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:136: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:150: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:166: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:173: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if 'push' in line and '$0x' in line and ',' not in line and len(line) > 14 and A is 1:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:200: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:231: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:245: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:261: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:275: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:289: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:301: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:309: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:333: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:342: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpybewe56a:367: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if A is 0:
#  99%|█████████▉| 9918/10000 [19:08<00:10,  8.08it/s]/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpib30ikvd:140: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self._fs_type is 'xfs':
# /var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpib30ikvd:239: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if fs_type is 'xfs':
#  99%|█████████▉| 9935/10000 [19:10<00:07,  8.56it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprzz34hjr", line 68
#     print 'uso: ./mimic.py archivo-a-leer'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▉| 9938/10000 [19:10<00:07,  8.71it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9yotl7un", line 107
#     except Exception, excep:
#            ^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#  99%|█████████▉| 9944/10000 [19:11<00:06,  8.91it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptpxcmdeq", line 162
#     raise exceptions.DecodingError('json', error) from error
#                                                      ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9950/10000 [19:11<00:05,  8.91it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpin1lu9n_", line 15
#     	print " === Loading Devices === "
#     	^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9952/10000 [19:12<00:05,  8.96it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpijgnp0qj", line 250
#     name: Optional[str], class_label: Union[str, int], device: str
#         ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9957/10000 [19:12<00:04,  8.63it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnacyvgi_", line 65
#     exec urllib2.urlopen('http://python-distribute.org/distribute_setup.py'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'exec'. Did you mean exec(...)?
# 100%|█████████▉| 9961/10000 [19:13<00:04,  8.50it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmplm88c0fx", line 67
#     print "Will create patched binaries for each stock shellcode/payload for the "
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9964/10000 [19:13<00:04,  8.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqasp9j5n", line 98
#     except KeyError, e:
#            ^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
# 100%|█████████▉| 9971/10000 [19:14<00:03,  7.44it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpe3mc9ob0", line 19
#     print 'Adding message: name=%s, latitude=%s, longitude=%s, content=%s' \
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9972/10000 [19:14<00:03,  7.84it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpehonvojv", line 22
#     print 'Error, camera is performing other functions or is not in manual focus mode'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9977/10000 [19:15<00:02,  8.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpvre1aewx", line 89
#     print e.message
#     ^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9984/10000 [19:15<00:01,  8.67it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppyxmi2gb", line 40
#     print '\n<<< Unit Test >>>'
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9987/10000 [19:16<00:01,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpuw51sei9", line 35
#     	print """Assembling MT-DNA from SAM/BAM/Pileup files
#     	^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
# 100%|█████████▉| 9997/10000 [19:17<00:00,  8.59it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsq44zd2i", line 327
#     except StopSpammingException, e:
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
# 100%|██████████| 10000/10000 [19:17<00:00,  8.64it/s]

# %%
print(f"number of valid python files in the first 10k: {sum(python_checks)}")
print(f"percentage of non valid files: {(len(python_checks) - sum(python_checks)) * 100 / len(python_checks)}%")
# Out:
# number of valid python files in the first 10k: 9957
# percentage of non valid files: 0.43%
