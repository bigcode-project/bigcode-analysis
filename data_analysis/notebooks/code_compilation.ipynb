# %% [markdown]
# ### BigCode python code dataset validation
#
# We find that in a subset of 10k filesin the **bigcode/python_safe_license**, only 0.24% of the files don't compile and have syntax errors

# %%
from datasets import load_dataset

# %%
data = load_dataset('bigcode/python_safe_license', streaming=True, split="train", use_auth_token=True, ignore_verifications=True)
# Out:
# Using custom data configuration bigcode--python_safe_license-05b1c2b44aa5d114

# %%
import tempfile
import subprocess
from tqdm import tqdm

def compile_python_code(sample):
    string = sample["content"]
    tmp = tempfile.NamedTemporaryFile()
    with open(tmp.name, "w") as f:
        f.write(string)
    py_command = "python{v} -m py_compile " + tmp.name
    
    try:
        subprocess.check_call(py_command.format(v=3).split())
        python3_works = True
    except subprocess.CalledProcessError:
        python3_works = False

    try:
        subprocess.check_call(py_command.format(v=2).split())
        python2_works = True
    except subprocess.CalledProcessError:
        python2_works = False

    return python2_works or python3_works

# %%
subset = list(data.shuffle(seed=42).take(10_000))

# %%
python_checks = []
for i in tqdm(range(len(subset))):
    python_checks.append(compile_python_code(subset[i]))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8lvbv_22", line 36
#     async def async_setup(hass: HomeAssistant, config: dict):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 1/10000 [00:00<35:30,  4.69it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpb8ma01rj", line 45
#     experiment_name: Optional[str] = None
#                    ^
# SyntaxError: invalid syntax
#
#   0%|          | 3/10000 [00:00<23:05,  7.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcwksz9n_", line 136
#     kernel = torch.Tensor([*(x[0].shape[2:])]) // torch.Tensor(list((m.output_size,))).squeeze()
#                            ^
# SyntaxError: invalid syntax
#
#   0%|          | 4/10000 [00:00<21:39,  7.69it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpw2xu7w6n", line 33
#     async def test_setup_loads_platforms(hass):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 5/10000 [00:00<21:00,  7.93it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfkhqgaz1", line 14
#     async def test_send_message_with_data(hass):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 8/10000 [00:01<19:15,  8.65it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpe18zujy8", line 23
#     self._id: int = 0
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 10/10000 [00:01<19:33,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwvc47_jn", line 47
#     async def test_async_update_support(hass):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 13/10000 [00:01<19:41,  8.45it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptg1cgj1z", line 47
#     CONF_NAME: f"{ZEROCONF_NAME}.{IPP_ZEROCONF_SERVICE_TYPE}",
#                                                             ^
# SyntaxError: invalid syntax
#
#   0%|          | 15/10000 [00:01<19:01,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpvawch9hx", line 62
#     print('{} / {}'.format(args.batch_size*(i+1), test_loader.num), end='\r')
#                                                                        ^
# SyntaxError: invalid syntax
#
#   0%|          | 16/10000 [00:01<19:03,  8.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmv10ayi5", line 21
#     async def mock_rflink(
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 17/10000 [00:02<18:57,  8.78it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpg_mfd5iw", line 77
#     async def validate_input(hass: core.HomeAssistant, data):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 18/10000 [00:02<19:00,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpm22bpzob", line 49
#     async def async_setup_platform(hass, config, async_add_entities, discovery_info=None):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 19/10000 [00:02<18:45,  8.87it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu57ugu_q", line 19
#     async def async_setup(hass: HomeAssistant, config: Config) -> bool:
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 23/10000 [00:02<19:56,  8.34it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptn27a6pn", line 28
#     def __init__(self, num_batches, *meters, prefix=""):
#                                                   ^
# SyntaxError: invalid syntax
#
#   0%|          | 28/10000 [00:03<19:53,  8.36it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp789dp2ny", line 106
#     return f"{self._name} {SENSORS[self._type]['name']}"
#                                                        ^
# SyntaxError: invalid syntax
#
#   0%|          | 29/10000 [00:03<19:46,  8.41it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmps47xxqwe", line 8
#     async def async_setup_platform(hass, config, async_add_entities, discovery_info=None):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 34/10000 [00:04<20:36,  8.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv9hp73lk", line 22
#     async def test_setup_missing_config(hass):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 35/10000 [00:04<20:51,  7.96it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptb7kgybk", line 37
#     def check_translations_directory_name(integration: Integration) -> None:
#                                                      ^
# SyntaxError: invalid syntax
#
#   0%|          | 39/10000 [00:04<19:51,  8.36it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpj2yi1z3c", line 37
#     async def async_setup(hass):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 42/10000 [00:05<19:11,  8.65it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpz4gv1yay", line 18
#     async def async_setup_entry(hass, config_entry, async_add_entities):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 43/10000 [00:05<19:24,  8.55it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpy0ytwkw3", line 13
#     class FluNearYouFlowHandler(config_entries.ConfigFlow, domain=DOMAIN):
#                                                                  ^
# SyntaxError: invalid syntax
#
#   0%|          | 45/10000 [00:05<19:57,  8.32it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpjsympion", line 55
#     f"Maximum ({minimum}) is not greater than minimum ({maximum})"
#                                                                  ^
# SyntaxError: invalid syntax
#
#   0%|          | 47/10000 [00:05<20:07,  8.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpelis_upr", line 35
#     async def internal_url_mock(hass):
#         ^
# SyntaxError: invalid syntax
#
#   0%|          | 48/10000 [00:05<20:33,  8.07it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdqxdn489", line 42
#     async def test_service_data_not_a_dict(hass, calls):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 49/10000 [00:05<20:55,  7.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpc8tnfi25", line 17
#     async def async_added_to_hass(self):
#             ^
# SyntaxError: invalid syntax
#
#   0%|          | 50/10000 [00:06<20:47,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_338re_c", line 46
#     async def async_get_service(hass, config, discovery_info=None):
#             ^
# SyntaxError: invalid syntax
#
#   1%|          | 54/10000 [00:06<27:03,  6.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwq9g7mjb", line 46
#     return os.path.join(TMP_DIR, f"{leaf_name}.json")
#                                                    ^
# SyntaxError: invalid syntax
#
#   1%|          | 62/10000 [00:08<26:51,  6.17it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_khk2kor", line 37
#     def _test_pipeline(self, nlp: Pipeline):
#                                 ^
# SyntaxError: invalid syntax
#
#   1%|          | 63/10000 [00:08<27:12,  6.09it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppy5kh1pv", line 38
#     async def async_setup(hass: HomeAssistant, config: ConfigType) -> bool:
#             ^
# SyntaxError: invalid syntax
#
#   1%|          | 64/10000 [00:08<27:04,  6.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3fpe51ld", line 111
#     f"{ATTR_START_DATE}, {ATTR_START_TIME}, {ATTR_END_DATE}, "
#                                                              ^
# SyntaxError: invalid syntax
#
#   1%|          | 65/10000 [00:08<27:06,  6.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpy7svy6gg", line 8
#     async def async_setup_platform(hass, config, async_add_entities, discovery_info=None):
#             ^
# SyntaxError: invalid syntax
#
#   1%|          | 66/10000 [00:08<26:07,  6.34it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4g2sgd4e", line 24
#     def prune_columns(file_schema: Schema, expected_schema: Schema) -> List[str]:
#                                  ^
# SyntaxError: invalid syntax
#
#   1%|          | 68/10000 [00:08<23:37,  7.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmsxwswlo", line 22
#     hass: core.HomeAssistant, service: Union[str, Collection[str]], callback: Callable
#         ^
# SyntaxError: invalid syntax
#
#   1%|          | 70/10000 [00:09<21:23,  7.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpt23admll", line 37
#     async def async_setup(hass, config):
#             ^
# SyntaxError: invalid syntax
#
#   1%|          | 72/10000 [00:09<20:12,  8.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdfjjyba3", line 32
#     def async_register(hass: HomeAssistantType, handler: "IntentHandler") -> None:
#                            ^
# SyntaxError: invalid syntax
#
#   1%|          | 75/10000 [00:09<19:03,  8.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpa3c042nh", line 2343
#     def _get_module(self, module_name: str):
#                                      ^
# SyntaxError: invalid syntax
#
#   1%|          | 79/10000 [00:10<19:02,  8.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp00ih0goy", line 87
#     def __init__(self, config: opt_cfg.OptimizationConfig):
#                              ^
# SyntaxError: invalid syntax
#
#   1%|          | 83/10000 [00:10<19:03,  8.67it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpetzo2bu_", line 1
#     def dencrypt(s: str, n: int = 13) -> str:
#                   ^
# SyntaxError: invalid syntax
#
#   1%|          | 88/10000 [00:11<18:31,  8.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsto44z9w", line 5
#     print(f"Getting all observations of track {track_id}")
#                                                         ^
# SyntaxError: invalid syntax
#
#   1%|          | 89/10000 [00:11<18:25,  8.97it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpirloisp6", line 59
#     def build_metrics(self, training: bool = True):
#                                     ^
# SyntaxError: invalid syntax
#
#   1%|          | 92/10000 [00:11<21:29,  7.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfxxyvjxl", line 16
#     ) from exc
#          ^
# SyntaxError: invalid syntax
#
#   1%|          | 96/10000 [00:12<21:08,  7.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptza80968", line 88
#     configuration: Union[str, Mapping],
#                  ^
# SyntaxError: invalid syntax
#
#   1%|          | 101/10000 [00:12<20:14,  8.15it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpstk8pchg", line 14
#     class AbstractDistribution(metaclass=abc.ABCMeta):
#                                         ^
# SyntaxError: invalid syntax
#
#   1%|          | 104/10000 [00:13<20:01,  8.24it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpq6oiynu_", line 33
#     input_type: str,
#               ^
# SyntaxError: invalid syntax
#
#   1%|          | 106/10000 [00:13<20:10,  8.17it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1uwjdzkp", line 43
#     print('\n=====\n{} | {}\n=====\n'.format(time.asctime(), msg), flush=True)
#                                                                         ^
# SyntaxError: invalid syntax
#
#   1%|          | 110/10000 [00:13<20:56,  7.87it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbkkgm_oy", line 14
#     def solution(num: int = 100) -> int:
#                     ^
# SyntaxError: invalid syntax
#
#   1%|          | 123/10000 [00:15<18:58,  8.67it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpn4ulsce_", line 28
#     def solution(n: int = 1000) -> int:
#                   ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 126/10000 [00:15<19:06,  8.61it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4t6a75o0", line 21
#     def f(x: float) -> float:
#            ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 129/10000 [00:16<19:01,  8.65it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppzcke6tz", line 16
#     database: Union[Dict[str, oft.FeaturesData], shelve.Shelf]
#             ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 130/10000 [00:16<19:26,  8.46it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprmoctn48", line 7
#     input_str: str = "The quick brown fox jumps over the lazy dog",
#              ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 141/10000 [00:17<18:43,  8.77it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnwwm6u_8", line 170
#     raise ValueError("'estimator' parameter must be a fitted estimator") from e
#                                                                             ^
# SyntaxError: invalid syntax
#
#   1%|▏         | 148/10000 [00:18<18:35,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8mwcvnzs", line 39
#     f = X[i] @ W
#              ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 151/10000 [00:18<19:07,  8.59it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2cczmku7", line 80
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 170/10000 [00:20<19:15,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcus4z8ob", line 12
#     async def index(
#         ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 172/10000 [00:21<18:29,  8.86it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmph8cy22sf", line 137
#     f'Failed to get PyPI versions for {package} with: {response.text}')
#                                                                      ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 179/10000 [00:21<17:59,  9.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdmxt5obu", line 14
#     status: int
#           ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 185/10000 [00:22<18:22,  8.90it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphkyrn2ux", line 71
#     pub_year = f'{b["year"]}'
#                             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 200/10000 [00:24<17:25,  9.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpys5vbxoy", line 7
#     async def add(
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 206/10000 [00:24<17:37,  9.26it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0x60k140", line 13
#     async def read_items(token: Optional[str] = Security(oauth2_scheme)):
#         ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 208/10000 [00:24<17:23,  9.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprf_s5o15", line 2
#     def __init__(self, name: str):
#                            ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 210/10000 [00:25<17:26,  9.36it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu_3tp7aj", line 7
#     async def cards_create(
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 213/10000 [00:25<17:51,  9.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp36fdp10r", line 7
#     async def read_items(q: str = Query(..., min_length=3)):
#         ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 214/10000 [00:25<17:41,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6hlmovn9", line 10
#     name: str
#         ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 217/10000 [00:25<17:40,  9.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp10od_jbm", line 12
#     async def common_parameters(q: str, skip: int = 0, limit: int = 100):
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 221/10000 [00:26<18:12,  8.95it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcal76dum", line 39
#     async def show_page(self, page_num):
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 226/10000 [00:27<19:04,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp545n7ivu", line 31
#     async def from_me(event: UserEvent):
#         ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 227/10000 [00:27<18:58,  8.58it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpolgleygu", line 11
#     async def main():
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 230/10000 [00:27<19:25,  8.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphc8pr_aw", line 12
#     diff_goi_df=pd.read_csv(f"{snakemake.input[0]}", header=0, sep="\t", index_col=False )
#                                                   ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 232/10000 [00:27<18:21,  8.87it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp053d5mnz", line 16
#     DÉLKA_PRODLEVY = 0.015
#      ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 234/10000 [00:27<18:07,  8.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcouilwxz", line 86
#     ckpt_pths = glob.glob(os.path.join(past_exp, f'{name}.ckpt'))
#                                                               ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 235/10000 [00:28<17:55,  9.08it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpssmewfq5", line 309
#     print '''\
#     ^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   2%|▏         | 237/10000 [00:28<17:47,  9.15it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcnapksce", line 38
#     vq_wav2vec = getattr(hubconf, f'vq_wav2vec_kmeans')(refresh=refresh)
#                                                      ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 241/10000 [00:28<17:52,  9.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3ocub5r7", line 26
#     async def recv(self):
#             ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 247/10000 [00:29<17:46,  9.15it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp19yrv8f7", line 41
#     print(f'usage: {sys.argv[0]:s} [--device device] image_out')
#                                                               ^
# SyntaxError: invalid syntax
#
#   2%|▏         | 248/10000 [00:29<17:47,  9.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmpjbmlp4", line 55
#     except EnvironmentError, e:
#            ^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   2%|▎         | 250/10000 [00:29<17:41,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpppzebhty", line 41
#     except tokenize.TokenError, e:
#            ^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   3%|▎         | 252/10000 [00:29<17:39,  9.20it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmph8gck1l_", line 466
#     **kwargs,
#             ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 264/10000 [00:31<17:50,  9.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptlsb_pbb", line 43
#     base_log_folder: str,
#                    ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 272/10000 [00:32<18:29,  8.77it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpovlilkei", line 112
#     _CURRENT_CONTEXT: List[Context] = []
#                     ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 273/10000 [00:32<18:45,  8.64it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqx2387ac", line 60
#     raise ValueError(f'The response contained an error: {response}')
#                                                                   ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 274/10000 [00:32<18:23,  8.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpb2aespvh", line 77
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 276/10000 [00:32<17:51,  9.07it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpm06cffc2", line 44
#     dag_id=f'{parent_dag_name}.{child_dag_name}',
#                                                ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 280/10000 [00:33<17:25,  9.30it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5jwoahvv", line 48
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 283/10000 [00:33<17:46,  9.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv83cpyss", line 177
#     def check_metric_scalar_gte(metric_name: str, value: int) -> Callable:
#                                            ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 284/10000 [00:33<17:49,  9.08it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu2l71yfe", line 130
#     template: jinja2.environment.Template
#             ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 288/10000 [00:33<17:57,  9.01it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwdrx3oe5", line 42
#     **{"are_dependents_done.return_value": False},
#                                                  ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 289/10000 [00:34<17:49,  9.08it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpx7wab2br", line 176
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 296/10000 [00:34<18:13,  8.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpicv8gn6g", line 429
#     args = [f'echo \'{return_value}\' > /airflow/xcom/return.json']
#                                                                  ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 300/10000 [00:35<18:30,  8.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmm9rko7z", line 97
#     print("Invalid -W option ignored:", msg, file=sys.stderr)
#                                                  ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 306/10000 [00:35<18:15,  8.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu0cszbqf", line 50
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 315/10000 [00:36<18:16,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkou43d3o", line 95
#     s3_destination_key=f'{s3_directory}/youtube_search_{s3_file_name}.json',
#                                                                           ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 317/10000 [00:37<18:49,  8.58it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpy3jhvv16", line 20
#     print 'deleting', filename
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 320/10000 [00:37<18:04,  8.93it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6n00fveh", line 72
#     upload_file = f'{TEST_FILE_PATH}_upload_1'
#                                              ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 323/10000 [00:37<18:09,  8.88it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpliv1rye9", line 611
#     yield from get_subactions()
#              ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 325/10000 [00:38<18:27,  8.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfigyzg4d", line 72
#     *,
#      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 329/10000 [00:38<18:39,  8.64it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgh43__eo", line 440
#     nonlocal processed, handle
#                      ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 330/10000 [00:38<18:51,  8.54it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3fag284y", line 80
#     def children(m: nn.Module):
#                   ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 334/10000 [00:39<17:27,  9.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4ircuuxr", line 67
#     "query": f"SELECT * FROM `{TEST_DATASET}.{TEST_TABLE_ID}`",
#                                                              ^
# SyntaxError: invalid syntax
#
#   3%|▎         | 338/10000 [00:39<17:38,  9.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdjy81zj4", line 69
#     print "Header tag: %s is %s" % (tag.name, tag.string.strip())
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 340/10000 [00:39<17:38,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpuzrr7uvy", line 58
#     print client.put(remote, fd, "text/plain")
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   3%|▎         | 344/10000 [00:40<17:32,  9.18it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp43dbtc9q", line 339
#     print args
#     ^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▎         | 351/10000 [00:40<17:41,  9.09it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpscax30vi", line 23
#     source: Union[int, str]
#           ^
# SyntaxError: invalid syntax
#
#   4%|▎         | 359/10000 [00:41<17:57,  8.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpephi87p9", line 41
#     classifier = lambda x, **kw: self.classifier(x, **kw, **kwargs).logits
#                                                         ^
# SyntaxError: invalid syntax
#
#   4%|▎         | 361/10000 [00:42<18:13,  8.82it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv9qrbmij", line 790
#     except Exception, error:
#            ^^^^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   4%|▎         | 364/10000 [00:42<18:00,  8.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp764re4yt", line 23
#     data: bytes
#         ^
# SyntaxError: invalid syntax
#
#   4%|▎         | 366/10000 [00:42<17:52,  8.99it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsldb_6ta", line 70
#     print "Found releases: %s" % ast.releases
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   4%|▎         | 371/10000 [00:43<17:33,  9.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppugxzjax", line 30
#     venv: VecEnv,
#         ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 375/10000 [00:43<17:20,  9.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpr_kiu4vq", line 5
#     print(f'{count}번 나무를 찍었습니다.')
#                                                  ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 378/10000 [00:44<19:24,  8.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqta873t5", line 49
#     print(f"{_DEBUG_lvls[lvl]}- {string} in {type(o)}")
#                                                      ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 379/10000 [00:44<19:17,  8.31it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpet6no4y8", line 326
#     deprecated_types.append(f"U{np.dtype(np.intp).name}")
#                                                        ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 385/10000 [00:44<17:39,  9.07it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcyb2iu9x", line 83
#     def _trace_distance_bound_(self) -> Optional[float]:
#                                      ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 386/10000 [00:44<17:41,  9.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpyqbelkt5", line 79
#     async def _makeApiCall(self, entry, *args, **kwargs):
#             ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 389/10000 [00:45<17:56,  8.92it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4_bjazp5", line 12
#     def __init__(self) -> None:
#                        ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 392/10000 [00:45<17:40,  9.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmph2wys542", line 34
#     def __init__(self, no_decomp: Callable[[ops.Operation], bool] = (lambda _: False)) -> None:
#                                 ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 395/10000 [00:45<17:19,  9.24it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0hpzrrvj", line 26
#     def random_normal_like(tensor: Tensor, mean: float = 0.0, std: float = 1.0,
#                                  ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 396/10000 [00:46<17:10,  9.32it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkj0qkb73", line 35
#     def generate_all_quirk_cell_makers() -> Iterator[CellMaker]:
#                                          ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 404/10000 [00:46<17:18,  9.24it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpavmwdm27", line 39
#     def __init__(self, op: NumpyOp, repeat: Union[int, Callable[..., bool]] = 1,
#                          ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 405/10000 [00:46<17:14,  9.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3wb1650d", line 31
#     qubit_order: Sequence['cirq.Qid'], acquaintance_size: int = 0, swap_gate: 'cirq.Gate' = ops.SWAP
#                ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 410/10000 [00:47<17:38,  9.06it/s]Sorry: TabError: inconsistent use of tabs and spaces in indentation (tmpa32rl3sk, line 104)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwx_k3opo", line 43
#     inputs: Union[None, str, Iterable[str]] = None,
#           ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 412/10000 [00:47<17:19,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpiz6le5zs", line 36
#     inputs: Union[str, Iterable[str]],
#           ^
# SyntaxError: invalid syntax
#
#   4%|▍         | 450/10000 [00:51<17:33,  9.07it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpn7o3qpf2", line 9
#     async def create_amilk(*, wallet_id: str, lnurl: str, atime: int, amount: int) -> AMilk:
#             ^
# SyntaxError: invalid syntax
#
#   5%|▍         | 467/10000 [00:53<17:22,  9.15it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmmo1l0sg", line 171
#     async def send_request(self, request_data):
#             ^
# SyntaxError: invalid syntax
#
#   5%|▍         | 481/10000 [00:55<17:12,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsmii6se3", line 47
#     input_arrays: Sequence[str] = (),
#                 ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 506/10000 [00:57<17:11,  9.20it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkq3v8brf", line 29
#     Projector.objects.create(name=f"Projector{index}")
#                                                     ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 510/10000 [00:58<17:07,  9.24it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4t9ot2bo", line 24
#     print(temp.data,end =' ')
#                         ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 535/10000 [01:01<17:12,  9.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1g3jpfq7", line 52
#     print(termcolor.colored("".join(nonStd), "red"), end="\r")
#                                                         ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 536/10000 [01:01<17:12,  9.17it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu5e_e1zp", line 26
#     log_url = f"https://commadataci.blob.core.windows.net/openpilotci/{ROUTE}/{i}/rlog.bz2"
#                                                                                           ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 539/10000 [01:01<17:06,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpavb9_4xb", line 47
#     		print "Min and Max values: " , xmin, xmax, ymin, ymax, zmin, zmax, numLines, "\n"
#     		^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   5%|▌         | 541/10000 [01:01<17:09,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpryz2gm5k", line 11
#     print(f"list_s3_by_prefix bucket: {bucket}, prefix: {prefix}")
#                                                                 ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 543/10000 [01:01<17:05,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmplshmavb8", line 31
#     return patch(f"selfdrive.thermald.power_monitoring.{name}", value)
#                                                              ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 544/10000 [01:02<17:05,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgxi4hcmj", line 67
#     formatted += f'<span class="token {span_class}">{string}</span>'
#                                                                    ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 546/10000 [01:02<16:52,  9.34it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv2_9h9rt", line 144
#     def read(self, location) -> Result:
#                              ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 547/10000 [01:02<16:58,  9.28it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpf_s6ks4v", line 37
#     prev_offroad_states: Dict[str, Tuple[bool, Optional[str]]] = {}
#                        ^
# SyntaxError: invalid syntax
#
#   5%|▌         | 548/10000 [01:02<17:07,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpn07khd5c", line 6
#     input_uri: 'ExternalArtifactUri',
#              ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 552/10000 [01:02<17:08,  9.18it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpicgwsabl", line 66
#     command: str = None,
#            ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 553/10000 [01:03<17:11,  9.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmplyfuy_iq", line 40
#     namespace: str,
#              ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 554/10000 [01:03<17:13,  9.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbcugoax_", line 128
#     p = Path(f"{route_path}--{n}")
#                                 ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 563/10000 [01:04<16:57,  9.28it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsrsuqj_o", line 22
#     data: HintModel
#         ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 573/10000 [01:05<16:56,  9.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6lal98t1", line 35
#     local_dir: str,
#              ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 576/10000 [01:05<16:56,  9.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppjn976rz", line 56
#     game: Game = self.assert_objects(Game)
#         ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 577/10000 [01:05<16:58,  9.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpx8g_hxxj", line 38
#     model_id: int,
#             ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 585/10000 [01:06<17:19,  9.06it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwvya3nvt", line 18
#     def __init__(self, child_space: gym.Space, max_len: int):
#                                   ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 586/10000 [01:06<17:03,  9.20it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu1wqjtyf", line 46
#     data: UserModel
#         ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 588/10000 [01:06<16:54,  9.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpt_171cdt", line 107
#     f"of running '{self._function_name}()', "
#     ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 596/10000 [01:07<17:39,  8.87it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmgk1iych", line 110
#     *query.extra_select,
#     ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 597/10000 [01:07<17:52,  8.77it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpo8hxjlxs", line 308
#     raise OSError("cannot write mode %s as BMP" % im.mode) from e
#                                                               ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 599/10000 [01:08<17:26,  8.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpeazxno9j", line 54
#     def __init__(self, path: Path) -> None:
#                            ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 609/10000 [01:09<17:15,  9.07it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_j1ftqvb", line 813
#     print 'xml: encoding =',encoding,'standalone =',standalone
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   6%|▌         | 610/10000 [01:09<17:41,  8.84it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpd9a_7a8k", line 259
#     def __init__(self, *args, transpose=(-1, -3), **kwargs):
#                                       ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 614/10000 [01:09<17:01,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp7pkjovs6", line 23
#     vae_save_period=1,
#                   ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 615/10000 [01:09<17:01,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfrj4kyhd", line 82
#     except ImportError,e:
#            ^^^^^^^^^^^^^
# SyntaxError: multiple exception types must be parenthesized
#   6%|▌         | 619/10000 [01:10<17:08,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpoa6h4fif", line 9
#     async def foo():
#         ^
# SyntaxError: invalid syntax
#
#   6%|▌         | 622/10000 [01:10<17:07,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp10gwhsx5", line 172
#     def __init__(self, *args, ignore_conflicts=False, **kwargs):
#                                              ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 631/10000 [01:11<17:21,  8.99it/s]Sorry: TabError: inconsistent use of tabs and spaces in indentation (tmpgvlh_l88, line 46)  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpydmpv5t4", line 53
#     raise ValueError(f'Invalid log strategy `{self.log_strategy}`!')
#                                                                   ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 634/10000 [01:11<17:06,  9.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpv8ik0tvo", line 15
#     def get_master_storage(video: dict) -> int:
#                                 ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 644/10000 [01:13<17:04,  9.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcsmhffnt", line 174
#     raise ValueError(f"bounding box format {bbox_fmt} not supported!")
#                                                                     ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 647/10000 [01:13<17:04,  9.13it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpokmsvy2e", line 10
#     ad = genfromtxt(f"../financial_data/MER.csv", delimiter=",", dtype=str)
#                                                ^
# SyntaxError: invalid syntax
#
#   6%|▋         | 649/10000 [01:13<17:15,  9.03it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpw_rmvbwr", line 14
#     ) from exc
#          ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 654/10000 [01:14<17:14,  9.03it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp6phuresf", line 48
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 657/10000 [01:14<17:15,  9.02it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpkn4vk5nu", line 20
#     def __init__(self, loop: asyncio.AbstractEventLoop) -> None:
#                            ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 658/10000 [01:14<18:13,  8.55it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwfay1hav", line 53
#     **self.conan_data["sources"][self.version],
#                                               ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 662/10000 [01:15<17:22,  8.96it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpwl6mm8z9", line 87
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 664/10000 [01:15<17:04,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp05kuvahx", line 20
#     def pass_context(f: F) -> F:
#                       ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 670/10000 [01:15<16:54,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpywy97wst", line 664
#     "err_msg": f"Field {output_fields[-1]} not exist"})
#                                                     ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 672/10000 [01:16<17:31,  8.87it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp53ct8hmt", line 54
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 674/10000 [01:16<17:19,  8.97it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpf9c3qzpd", line 46
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 679/10000 [01:16<17:20,  8.96it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9km1c43h", line 44
#     def parse(self) -> List[dict]:
#                     ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 684/10000 [01:17<17:10,  9.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1w79ei_u", line 10
#     ad = genfromtxt(f"../financial_data/RRHI.csv", delimiter=",", dtype=str)
#                                                 ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 688/10000 [01:17<16:44,  9.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpc7821nt1", line 50
#     tools.get(**self.conan_data["sources"][self.version], destination=self._source_subfolder, strip_root=True)
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 690/10000 [01:18<16:38,  9.33it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsdam1p0w", line 29
#     def __init__(self, socket: AsyncSocketStream, ssl_context: SSLContext = None):
#                              ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 694/10000 [01:18<16:57,  9.15it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpzmsz7ixs", line 51
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 700/10000 [01:19<16:59,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2yg6is5s", line 29
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 703/10000 [01:19<16:50,  9.20it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnte71a9u", line 45
#     tools.get(**self.conan_data["sources"][self.version],
#                                                         ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 705/10000 [01:19<17:32,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu3askhn_", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu3askhn_", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 707/10000 [01:19<17:19,  8.94it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp544ny8bi", line 201
#     **kwargs,
#             ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 709/10000 [01:20<17:01,  9.10it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp891uvq4h", line 188
#     **kwargs,
#             ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 711/10000 [01:20<16:50,  9.19it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp3igyirda", line 54
#     def num_parameters(self, only_trainable: bool = False) -> int:
#                                            ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 714/10000 [01:20<16:51,  9.18it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp693qaead", line 337
#     async def fetch_time(self, params={}):
#             ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 717/10000 [01:21<16:58,  9.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbfv_zcgy", line 97
#     last_hidden_state: torch.FloatTensor
#                      ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 724/10000 [01:21<16:56,  9.12it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpw0khj9jv", line 39
#     raise BadPeerError(f'{message} returned bad result type '
#                                                             ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 727/10000 [01:22<16:57,  9.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpya2d6nl5", line 13
#     async def work(exchange_id):
#             ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 733/10000 [01:22<16:45,  9.22it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpu64a0_oq", line 40
#     if not utils.check_file_exists(f"{folder1}/{generated_output_rst}"):
#                                                                      ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 738/10000 [01:23<17:27,  8.84it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpcayqbept", line 46
#     error = Excepcion("42P10","Semantico",f"La columna <<{id}>> no existe, Error en el Constraint",self.linea,self.columna)
#                                                                                                  ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 741/10000 [01:23<17:00,  9.08it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpukwfrpbd", line 49
#     var_array = self.print(environment)
#                          ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 742/10000 [01:23<16:50,  9.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8nhp_czf", line 7
#     def __init__(self, tipo, data:object):
#                                  ^
# SyntaxError: invalid syntax
#
#   7%|▋         | 747/10000 [01:24<17:04,  9.03it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2_r7p98q", line 178
#     consola.append(f"42P01 	undefined_table, Tabla no existe -> '{err}'") #NO EXISTE TABLAS
#                            	                                           ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 764/10000 [01:26<16:42,  9.21it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpszc5a7f3", line 13
#     def analizar_semanticamente(self, entorno: Tabla_de_simbolos, arbol:Arbol):
#                                              ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 770/10000 [01:26<16:44,  9.18it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsaqtcpch", line 21
#     def ejecutar(self, ent: Entorno):
#                           ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 771/10000 [01:27<16:47,  9.16it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9isjotbe", line 254
#     dato = Excepcion(0,"Error Lexico", f"El Simbolo << {t.value[0]} >> No Pertenece al Lenguaje", t.lexer.lineno, col)
#                                                                                                ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 787/10000 [01:28<17:24,  8.82it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp380e514g", line 69
#     print r[0], t, "\"" + d + "\"", r[2]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   8%|▊         | 789/10000 [01:29<17:41,  8.68it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9zjx973r", line 56
#     async def send_notice(
#             ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 793/10000 [01:29<16:58,  9.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppu07mta9", line 237
#     __serialized_fields: Optional[FrozenSet[str]] = None
#                        ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 795/10000 [01:29<17:15,  8.89it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp90iiityi", line 63
#     raise ValueError(f"Capacity number {capacity} is invalid")
#                                                             ^
# SyntaxError: invalid syntax
#
#   8%|▊         | 805/10000 [01:30<16:57,  9.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmprd2qgptq", line 39
#     def setup_class(cls) -> None:
#                          ^
# SyntaxError: invalid syntax
#
# ...
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9756/10000 [1:14:48<00:29,  8.33it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8hubeuz5", line 36
#     *,
#      ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9760/10000 [1:14:48<00:28,  8.52it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpg3ofr1hf", line 46
#     _tune_pg_prefix = f"__tune_{uuid.uuid4().hex[:8]}__"
#                                                        ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9761/10000 [1:14:48<00:28,  8.46it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqqxqv20c", line 169
#     def _format_msg(msg: str,
#                        ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9762/10000 [1:14:48<00:28,  8.41it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpbmw2s7ma", line 115
#     f'keras_distribute_strategy_class={cls}. '
#     ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9764/10000 [1:14:48<00:27,  8.53it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpctl6bcac", line 82
#     def __str__(self) -> str:
#                       ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9769/10000 [1:14:49<00:27,  8.29it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpiio44__0", line 5
#     def to_dict_key(key: str):
#                        ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9770/10000 [1:14:49<00:27,  8.50it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpsuhcsms_", line 285
#     print(_display_dict.get(cell, "?"), end=" ")
#                                            ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9775/10000 [1:14:50<00:27,  8.24it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpynwx9zvx", line 20
#     print(yh[row][col], end='\t')
#                            ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9779/10000 [1:14:50<00:26,  8.29it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpvwljjh6y", line 68
#     self.restart_node(0, extra_args=[f'-mocktime={t}', '-blockversion=1337'])
#                                                     ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9781/10000 [1:14:51<00:27,  8.00it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpn6yvgtwt", line 11
#     print(f'O valor digitado foi {n} e a sua porção inteira é {int(n)}')
#                                                                          ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9782/10000 [1:14:51<00:26,  8.29it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpdaicrqgz", line 18
#     def __init__(self, live: "Live", refresh_per_second: float) -> None:
#                            ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9786/10000 [1:14:51<00:24,  8.57it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpxt7irv7z", line 11
#     def create_objects_in_time(data: dict)->list:
#                                    ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9788/10000 [1:14:51<00:25,  8.40it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2bkpby95", line 112
#     print("ERROR: no image filename provided.", file=sys.stderr)
#                                                     ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9792/10000 [1:14:52<00:23,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgi1jovzv", line 35
#     def forward(self, samples: NestedTensor):
#                              ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9794/10000 [1:14:52<00:24,  8.51it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmppguu6s0d", line 30
#     async def raffle(self, ctx: Context):
#         ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9796/10000 [1:14:52<00:23,  8.69it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpy8w1puuw", line 87
#     fidelity: FIDELITY,
#             ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9806/10000 [1:14:53<00:23,  8.32it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp77dh_7e4", line 16
#     with open(f"{folder}/{filename}", "r") as f:
#                                    ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9808/10000 [1:14:54<00:22,  8.42it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9itb2qqs", line 133
#     print(f"Loading data from {item_item_file_path}")
#                                                    ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9812/10000 [1:14:54<00:21,  8.57it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpx3pk4ibr", line 134
#     class BaseGradientBoosting(BaseEnsemble, metaclass=ABCMeta):
#                                                       ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9816/10000 [1:14:55<00:24,  7.56it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpll1kok9a", line 108
#     print 'im_proposals: {:d}/{:d} {:.3f}s' \
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  98%|█████████▊| 9820/10000 [1:14:55<00:21,  8.25it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2uohq_rv", line 5
#     async def run(self):
#             ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9823/10000 [1:14:56<00:20,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp05yiruqt", line 115
#     print(f'Parsing structure {structure_id}...')
#                                                ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9836/10000 [1:14:57<00:18,  8.85it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp8xjmkwx9", line 28
#     def test(server_proc: subprocess.Popen, browser: Chrome):
#                         ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9837/10000 [1:14:57<00:18,  8.90it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp4cn7x5er", line 40
#     class Submitter(object, metaclass=abc.ABCMeta):
#                                      ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9846/10000 [1:14:58<00:17,  8.71it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfiz_kgnf", line 14
#     print(f"|> {msg}")
#                     ^
# SyntaxError: invalid syntax
#
#  98%|█████████▊| 9848/10000 [1:14:58<00:17,  8.83it/s]SyntaxError: future feature annotations is not defined (tmpq40wb8dw, line 19)
#
#  98%|█████████▊| 9849/10000 [1:14:59<00:17,  8.69it/s]SyntaxError: future feature annotations is not defined (tmprf00kd9d, line 26)
#
#  98%|█████████▊| 9850/10000 [1:14:59<00:16,  8.83it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpqs2hvc_5", line 92
#     job_class: Type[base_jobs.JobBase],
#              ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9854/10000 [1:14:59<00:16,  8.65it/s]SyntaxError: future feature annotations is not defined (tmpyq4v03sv, line 17)
#
#  99%|█████████▊| 9855/10000 [1:14:59<00:17,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp79ybwxvt", line 50
#     print "Cartpole robot now spinning"
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9858/10000 [1:15:00<00:16,  8.42it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp89lkvhhr", line 18
#     id: int = ormar.Integer(primary_key=True)
#       ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9862/10000 [1:15:00<00:17,  7.81it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpfkdv06ir", line 22
#     model_cls: Type["Model"],
#              ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9864/10000 [1:15:00<00:16,  8.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpuyjal8w8", line 15
#     def asset_from_config(config: Config, asset_name: str, partition_path=None):
#                                 ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9868/10000 [1:15:01<00:15,  8.77it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpa0ww1f15", line 99
#     print args
#     ^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#  99%|█████████▊| 9870/10000 [1:15:01<00:15,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0vs6s6op", line 38
#     data = data.replace(f'<{k}>', v)
#                                ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9871/10000 [1:15:01<00:15,  8.60it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp695tc31u", line 23
#     async def test_async_setup_entry_default(hass: HomeAssistant):
#         ^
# SyntaxError: invalid syntax
#
#  99%|█████████▊| 9872/10000 [1:15:01<00:14,  8.70it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpki06gkmi", line 117
#     logger.info(f'[Pretrain epoch {str(epoch)}]')
#                                                ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9880/10000 [1:15:02<00:14,  8.48it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpxjbtq2eo", line 12
#     def __init__(self, request: Request):
#                               ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9882/10000 [1:15:03<00:14,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpefpozeve", line 487
#     return qml.expval(qml.PauliZ(0) @ qml.PauliZ(1) @ qml.PauliZ(2))
#                                     ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9883/10000 [1:15:03<00:14,  8.11it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_g2ourmm", line 27
#     logger.debug(f"encountered exception on retry #{i}: {e!r}")
#                                                              ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9884/10000 [1:15:03<00:13,  8.36it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpznctn3pe", line 71
#     def _tuplify(v: Optional[Iterable]) -> Optional[Tuple]:
#                   ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9887/10000 [1:15:03<00:13,  8.49it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp60wg7fwn", line 51
#     def __init__(self, attr_name, method_name, *, doc_sub=None):
#                                                 ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9889/10000 [1:15:03<00:13,  8.14it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp56v1nzqv", line 36
#     def __init__(self, type_: str, data: Any) -> None:
#                             ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9894/10000 [1:15:04<00:13,  8.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpt2mfh4ih", line 77
#     alias = os.path.join(tempdir, f"{i}.jar" if not os.path.isdir(cp) else f"{i}")
#                                            ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9903/10000 [1:15:05<00:12,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp557k3b4k", line 9
#     def test_bot(self) -> None:
#                        ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9905/10000 [1:15:05<00:11,  8.27it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp85ku7iv0", line 33
#     backend: IBMBackend,
#            ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9907/10000 [1:15:06<00:11,  8.23it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp1xgslovv", line 84
#     log_level: LogLevel
#              ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9909/10000 [1:15:06<00:11,  8.09it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_i8xxrnu", line 17
#     def get_bot_message_handler(bot_name: str) -> Any:
#                                         ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9917/10000 [1:15:07<00:09,  8.60it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp0yru7o0b", line 137
#     **counter), end="", file=sys.stderr)
#                    ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9919/10000 [1:15:07<00:09,  8.75it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp_jfyyfha", line 38
#     def retry(ExceptionToCheck: Any, tries: int = 4, delay: float = 3, backoff: float = 2):
#                               ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9920/10000 [1:15:07<00:09,  8.73it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2killaaa", line 16
#     def __init__(self, functions: dict = None, operators: dict = None,
#                                 ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9921/10000 [1:15:07<00:09,  8.69it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmphco22uh3", line 52
#     args.preprocessed_data_dir, args.speaker_A_id, f"{args.speaker_A_id}_normalized.pickle"))
#                                                                                           ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9923/10000 [1:15:07<00:09,  8.45it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpnwo6666q", line 127
#     command = command + f"grep -r {search_pattern} {ROOT_DIR_TO_SEARCH};"
#                                                                         ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9924/10000 [1:15:08<00:09,  8.00it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpr30vlwp8", line 20
#     def xml2nodes(xml_content: Union[str, bytes]):
#                              ^
# SyntaxError: invalid syntax
#
#  99%|█████████▉| 9934/10000 [1:15:09<00:08,  8.04it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp20ai0gbs", line 37
#     def check_availability_db(self) -> None:
#                                     ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9957/10000 [1:15:12<00:05,  7.31it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptzi1nm7v", line 47
#     matrix_evals_compĺement = 1 - matrix_evals
#                      ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9960/10000 [1:15:12<00:04,  8.17it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2hi2v5e5", line 63
#     scene_path = f'{scene_path}_{i:02d}'
#                                        ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9968/10000 [1:15:13<00:03,  8.38it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpganp3sit", line 26
#     def __init__(self, arg: Any, is_argument: bool = True) -> None:
#                           ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9969/10000 [1:15:13<00:03,  8.50it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp08yebpol", line 72
#     def cnn2d_depthwise_tf(image: np.ndarray,
#                                 ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9971/10000 [1:15:14<00:03,  8.66it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmptxbdwa5z", line 19
#     logger: Logger,
#           ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9981/10000 [1:15:15<00:02,  7.98it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpmcahs6o7", line 59
#     num_bins: int = 1024,
#             ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9987/10000 [1:15:16<00:01,  8.26it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpksqt1h5x", line 167
#     ), flush=True)
#             ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9988/10000 [1:15:16<00:01,  8.41it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpm63_5kn2", line 32
#     def new_temp_dir(prefix: str = None,
#                            ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9990/10000 [1:15:16<00:01,  8.55it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2aixrfd3", line 17
#     return edict(token=token, message=f"Set the header 'Authorization' to 'Bearer {token}'")
#                                                                                           ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9991/10000 [1:15:16<00:01,  8.35it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp9sys3xce", line 34
#     path: Path
#         ^
# SyntaxError: invalid syntax
#
# 100%|█████████▉| 9995/10000 [1:15:17<00:00,  8.50it/s]  File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpeenkfnrr", line 65
#     objective: str,
#              ^
# SyntaxError: invalid syntax
#
# 100%|██████████| 10000/10000 [1:15:17<00:00,  2.21it/s]

# %%
print(f"number of valid python files in the first 10k: {sum(python_checks)}")
print(f"percentage of non valid files: {(len(python_checks) - sum(python_checks)) * 100 / len(python_checks)}%")
# Out:
# number of valid python files in the first 10k: 9976
# percentage of non valid files: 0.24%

# %% [markdown]
# ### Examples of files that don't compile

# %%
# show which files weren't valid
for i, e in enumerate(python_checks):
    if not e:
        print(i)
# Out:
# 705
# 1412
# 1490
# 1584
# 1962
# 2378
# 2431
# 2555
# 2581
# 2659
# 3044
# 3060
# 3069
# 3711
# 3837
# 4629
# 6101
# 6901
# 6917
# 6920
# 7794
# 8084
# 8560
# 9495

# %%
compile_python_code(subset[705])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5r13si_2", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp5r13si_2", line 11
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax
# False

# %%
compile_python_code(subset[1412])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmpgk6cray7", line 11
#     from tensorflow.keras.metrics import AUC, MeanSquaredError, RootMeanSquaredError,
#                                                                                      ^
# SyntaxError: trailing comma not allowed without surrounding parentheses
# Sorry: IndentationError: unexpected indent (tmpgk6cray7, line 12)
# False

# %%
compile_python_code(subset[1490])
# Out:
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2zt_z_cm", line 167
#     elif:
#         ^
# SyntaxError: invalid syntax
#   File "/var/folders/yr/snw4cq790975mv7_mbwkxm500000gn/T/tmp2zt_z_cm", line 167
#     elif:
#         ^
# SyntaxError: invalid syntax
# False
