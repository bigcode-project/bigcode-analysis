# %% [markdown]
# ## Analysis and evaluation of PII regexes

# %% [markdown]
# In this notebook we do some exploratory analysis of our PII detection tools using the annotated dataset, we observe that:
# 1. For SSH & API keys detection:
# * detect-secrets tool has a very low recall (detects 2 out of 37 keys) so we will miss a lot of keys if we use it (removing filters doesn't help)
# * our regex for keys: https://regex101.com/r/pndDnd/1 :
#     * has a high recall (detects 28 out of 37 keys, and probably more because some keys had dots inside so the regex split them into multiple keys)
#     * has many false positives that are paths, words attached by ":" or "_" you can find them in `./experiments/before_gibberish_keys.txt`
#     * one solution to increase precision was to use a **Gibberish detector**, if a detected key is not labeled as gibberish (not word like) we don't keep it,
#     this removes 174 false positives that you can find in `./experiments/before_gibberish_keys.txt`
#     * **TO IMPROVE:**
#     * Some hashes are not labelled as gibberish by the gibberish detector(=> not filtered), not sure if they are really secrets, for an example see `./experiments/file_with_hashes.txt`
#     * There are still some false positives like name/path (labeled as gibberish) in this format "e2e_mask_rcnn_X-152-32x8d-FPN-IN5k_1.44x" and "//deno.land/std@0.142.0/testing/asserts.ts"
#     * If there is an "=" or "id=" in front of the key it is detected
#     * Some instances like "f47dbc9c:" and "dc22a3aa:" are detected, tehy seems like ids of patch releases, their context is saved in `./experiments/short_keys_patch_releases.txt`
#     * You can check all detected keys by looking for 'KEY' tags in `./experiments/list_detected_pii.txt`
# * TODO: get precision numbers and try adding more filters (from detect-secrets fore example)
# 2. For email detection:
# * **TO IMPROVE:**
# * our regex https://regex101.com/r/8CsR5P/1 and the updated bigscience regex https://regex101.com/r/LNwpG1/1 labelled a lot of samples like "dusk-network/icon@4.5.0" as emails
# * the updated bigscience regex doesn't detect well emails with are between "<" and ">" as in `<email>`.
# * our regex detected noreply@127.0.0.1 as an email
# * both regexes have a high recall on the list of emails we detected (without delimiters)
# * TODO: more comparison of the two regexes and precision/recall numbers and use of context detection
# 3. IP addresses: TODO

# %%
from datasets import load_dataset

# this dataset has lists of PII without context
ds = load_dataset("loubnabnl/pii-instances", use_auth_token=True, split="train")
# Out:
# Downloading readme:   0%|          | 0.00/896 [00:00<?, ?B/s]
# Using custom data configuration loubnabnl--pii-instances-b56ea5fc2b13487c
# Downloading and preparing dataset None/None to /Users/loubnabenallal/.cache/huggingface/datasets/loubnabnl___parquet/loubnabnl--pii-instances-b56ea5fc2b13487c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/17.1k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /Users/loubnabenallal/.cache/huggingface/datasets/loubnabnl___parquet/loubnabnl--pii-instances-b56ea5fc2b13487c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
from utils.emails_ip_addresses_detection import detect_email_addresses
from utils.keys_detection import detect_keys

# %%
# small test
text = """this is a test example with an email random@hf.co and address 10.1.1.1
          aws_access_key_id=AKIAIOSFODNN7EXAMPLE
          aws_secret_access_key=wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY
          randomstring=b3BlbnNzaC1rZXktdjEAAAAACmFlczI1Ni1jdHIAAAAGYmNyeXB0AAAAGAAAABDHn"""
keys = detect_keys(text)
emails_ip_adresses = detect_email_addresses(text, new_email_regex=False)

# %%
print(keys)
# Out:
# [{'tag': 'AWS Access Key', 'value': 'AKIAIOSFODNN7EXAMPLE', 'start': 99, 'end': 119}]

# %%
print(emails_ip_adresses)
# Out:
# [{'tag': 'EMAIL', 'value': 'random@hf.co', 'start': 37, 'end': 49}, {'tag': 'IP_ADDRESS', 'value': '10.1.1.1', 'start': 62, 'end': 70}]

# %%
other_keys = detect_email_addresses(text, tag_types={"KEY"}, new_email_regex=False)
other_keys
# Out:
# [{'tag': 'KEY',
#   'value': '=wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY',
#   'start': 151,
#   'end': 192},
#  {'tag': 'KEY',
#   'value': '=b3BlbnNzaC1rZXktdjEAAAAACmFlczI1Ni1jdHIAAAAGYmNyeXB0AAAAGAAAABDHn',
#   'start': 215,
#   'end': 281}]

# %% [markdown]
# ## Tests
# Let's test the pipelines on our PII instances

# %% [markdown]
# Due to an issue with LighTag, we can't download annotations with the reviews, we will need to manually clean the samples and remove empty samples we added to the dataset to have the same number of rows.

# %%
# select sample correct api samples
ds_api = ds.select([i for i in range(17) if i not in [7, 8, 13, 14, 15]] + [i for i in range(43, 80) if i not in [44, 63, 69, 72]])

# %%
len(ds_api["API_KEY"])
# Out:
# 45

# %%
api_keys_clean = set(ds_api["API_KEY"])

# %%
len(api_keys_clean)
# Out:
# 30

# %%
ssh_keys_clean = ds["SSH_KEY"][:7]
ssh_keys_clean
# Out:
# ['6622386f8d83dc9efefb8c03a4dbfc18e7928d89ffc2ec3e2feb9473e8f410c9',
#  '546d57b6c88c2be7517759c016c0bf0313dfcc14adfcb43967f3c5d24657f366',
#  '76d8ae334545bbdf2db49414c25d2cfd8685e7b6187f119b28e93ad9c5118e9d',
#  '43e0352fee07fa5b92dd22e557cb1d050ccde0cf97273e02f694930695b15134',
#  'c9eb8a1102d0a68cafc93f22df73445b8f69706f3322285f9a2f623a28df0176',
#  'eff634a68a01d081c0bdc51752dfa0709781f0e4',
#  '4d986a461d1b24bb5776fb49063b9a1891939f336b306a6bc75f58d0a4e98bcb']

# %%
addresses_clean = ds["IP_ADDRESS"][:95]

# %% [markdown]
# Detect API keys

# %%
detect_secrets_results = []
regexes_results = []
detect_secrets_nb = 0
regexes_nb = 0
for key in api_keys_clean:
    output_1 = detect_keys(key)
    output_2 = detect_email_addresses(key, tag_types={"KEY"}, new_email_regex=False)
    if output_1:
        detect_secrets_nb += 1
        detect_secrets_results.append(output_1)
    if output_2:
        regexes_nb += 1
        regexes_results.append(output_2)

# %%
print(f"nb dectected by detect-secrets: {detect_secrets_nb}")
print(f"nb dectected by regexes: {regexes_nb}")
print(f"number true API keys: {len(api_keys_clean)}")
# Out:
# nb dectected by detect-secrets: 2
# nb dectected by regexes: 21
# number true API keys: 30

# %%
detect_secrets_results
# Out:
# [[{'tag': 'JSON Web Token',
#    'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ.',
#    'start': 0,
#    'end': 192}],
#  [{'tag': 'JSON Web Token',
#    'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ.',
#    'start': 0,
#    'end': 192}]]

# %% [markdown]
# detect-secrets has a very low recall: 2 out of 30, let's anlyze the regex detections

# %%
res = 0
values = []
for i, elem in enumerate(regexes_results):
    if len(elem) != 1:
        print(f"\ndetection was split at {i} for {elem}\n")
    else:
        value = elem[0]["value"]
        if value in api_keys_clean:
            res += 1
            values.append(value)
        else:
            print(f"\nwrong detection at {i} for {value}\n")
print(f"Number of correctly detected strings: {res}")
# Out:
# wrong detection at 6 for ECDHE-RSA-AES128-GCM-SHA256:ECDHE-RSA-RC4-SHA:ECDHE-RSA-AES128-SHA:AES128-GCM-SHA256:RC4:HIGH:
#
#
# wrong detection at 7 for 476611152863-ltgqfk9jhq1vsenin5039n58ogkraltb
#
#
# detection was split at 11 for [{'tag': 'KEY', 'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9', 'start': 0, 'end': 36}, {'tag': 'KEY', 'value': 'eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ', 'start': 37, 'end': 191}, {'tag': 'KEY', 'value': 'D8ja66bnLxJ3bsJlaKRtOquu8XbibjNCyFxJpI7vafc', 'start': 192, 'end': 235}]
#
#
# detection was split at 12 for [{'tag': 'KEY', 'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9', 'start': 0, 'end': 36}, {'tag': 'KEY', 'value': 'eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ', 'start': 37, 'end': 191}, {'tag': 'KEY', 'value': '8X-fBRUHdrwtkTLcOFAsW-vvvqCzmkZKM2gQgHNkBKk', 'start': 192, 'end': 235}]
#
# Number of correctly detected strings: 17

# %%
print("missed keys")
# three of them were just truncated because they contained dots inside: not sure they are real keys
for key in api_keys_clean:
    if key not in values:
        print(key)
# Out:
# missed keys
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN0123456789
# ECDHE-RSA-AES128-GCM-SHA256:ECDHE-RSA-RC4-SHA:ECDHE-RSA-AES128-SHA:AES128-GCM-SHA256:RC4:HIGH:!MD5:!aNULL:!EDH:!CAMELLIA
# 476611152863-ltgqfk9jhq1vsenin5039n58ogkraltb.apps.googleusercontent.com
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN
# mfxl'vmsdv';mfdb'fdamlmdsvfdkfnjn
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ.D8ja66bnLxJ3bsJlaKRtOquu8XbibjNCyFxJpI7vafc
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ.8X-fBRUHdrwtkTLcOFAsW-vvvqCzmkZKM2gQgHNkBKk
# 2(iwreobf4b(-=h_p=^!obgxdgn3_*s!17=_3wc4dun9_y^q+c
# rSHvhgdOQUB4KMc5JS1alzhg
# 6595b64144ccf1df
# AIzaasdf
# 0123456789abcdefghijklmno
# ABCDEFGHIJKLMNabcdefghijklmnopqrstuvwxyz0123456789

# %% [markdown]
# Detect SSH keys

# %%
detect_secrets_results = []
regexes_results = []
detect_secrets_nb = 0
regexes_nb = 0
for key in ssh_keys_clean:
    output_1 = detect_keys(key)
    output_2 = detect_email_addresses(key, tag_types={"KEY"}, new_email_regex=False)
    if output_1:
        detect_secrets_nb += 1
        detect_secrets_results.append(output_1)
    if output_2:
        regexes_nb += 1
        regexes_results.append(output_2)

# %%
print(f"nb dectected by detect-secrets: {detect_secrets_nb}")
print(f"nb dectected by regexes: {regexes_nb}")
print(f"number true ssh keys: {len(ssh_keys_clean)}")
# Out:
# nb dectected by detect-secrets: 0
# nb dectected by regexes: 7
# number true ssh keys: 7

# %%
res = 0
values = []
for i, elem in enumerate(regexes_results):
    if len(elem) != 1:
        print(f"\ndetection was split at {i} for {elem}\n")
    else:
        value = elem[0]["value"]
        if value in ssh_keys_clean:
            res += 1
            values.append(value)
        else:
            print(f"\nwrong detection at {i} for {value}\n")
print(f"number of correctly detected strings: {res}")
# Out:
# number of correctly detected strings: 7

# %% [markdown]
# Remarks & questions:
# * some of the keys missed included dots, can API keys include dots?
# * add this regex to detect-secrets plugins to use filters on top of it ?
# Observations:
# * detect-secrets is not able to detect most API keys and all SSH keys
# * our regex for keys detects all shh keys ad 17 out of 30, 2 keys are split into 3 parts because they had two dots inside, and most of the keys left may not be real API keys
#
# =>
# * detect-secrets has a very low recall (even with no filters), the other secret keywords have many false positives so we can't add them.
# * our regex seems to have a high recall(very few missed positives/keys)
# * let's measure its precision by running it on the original code files

# %%
from datasets import load_dataset

ds_full = load_dataset("bigcode/pii-for-code", use_auth_token=True, split="train")
# Out:
# Using custom data configuration bigcode--pii-for-code-2810c83b744e2a86
# Found cached dataset json (/Users/loubnabenallal/.cache/huggingface/datasets/bigcode___json/bigcode--pii-for-code-2810c83b744e2a86/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)

# %%
from detect_pii import scan_pii_batch_viz

examples = ds_full.select(range(100))
outputs = scan_pii_batch_viz(examples, key_detector="regex", new_email_regex=False)
# Out:
# id: 6 for detectedt key: 'f47dbc9c:' in context: s@5.0.2
#   - @dusk-network/button@5.0.2
#   - @dusk-network/menu@5.0.2
#
# ## 5.0.1
#
# ### Patch Changes
#
# - f47dbc9c: Release
# - Updated dependencies [f47dbc9c]
#   - @dusk-network/icon@5.0.1
#   - @dusk-network/helpers@5.
#
# id: 6 for detectedt key: 'dc22a3aa:' in context: s@3.0.7
#   - @dusk-network/button@3.0.7
#   - @dusk-network/menu@3.0.7
#
# ## 3.0.6
#
# ### Patch Changes
#
# - dc22a3aa: testing changesets
# - Updated dependencies [dc22a3aa]
#   - @dusk-network/icon@3.0.6
#   - @dusk-network

# %%
outputs
# Out:
# [{'index': 0,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52}]},
#  {'index': 1,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529}]},
#  {'index': 2,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817}]},
#  {'index': 3,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443}]},
#  {'index': 4,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443}]},
#  {'index': 5,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443},
#    {'tag': 'EMAIL', 'value': 'info@srampos.com', 'start': 195, 'end': 211}]},
#  {'index': 6,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443},
#    {'tag': 'EMAIL', 'value': 'info@srampos.com', 'start': 195, 'end': 211},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.5',
#     'start': 116,
#     'end': 139},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.5',
#     'start': 145,
#     'end': 171},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.5',
#     'start': 177,
#     'end': 202},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.5',
#     'start': 208,
#     'end': 231},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.4',
#     'start': 321,
#     'end': 344},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.4',
#     'start': 350,
#     'end': 376},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.4',
#     'start': 382,
#     'end': 407},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.4',
#     'start': 413,
#     'end': 436},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.3',
#     'start': 526,
#     'end': 549},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.3',
#     'start': 555,
#     'end': 581},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.3',
#     'start': 587,
#     'end': 612},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.3',
#     'start': 618,
#     'end': 641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.2',
#     'start': 731,
#     'end': 754},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.2',
#     'start': 760,
#     'end': 786},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.2',
#     'start': 792,
#     'end': 817},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.2',
#     'start': 823,
#     'end': 846},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.1',
#     'start': 936,
#     'end': 959},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.1',
#     'start': 965,
#     'end': 991},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.1',
#     'start': 997,
#     'end': 1022},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.1',
#     'start': 1028,
#     'end': 1051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.0',
#     'start': 1161,
#     'end': 1184},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.0',
#     'start': 1190,
#     'end': 1216},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.0',
#     'start': 1222,
#     'end': 1247},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.0',
#     'start': 1253,
#     'end': 1276},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.12',
#     'start': 1374,
#     'end': 1398},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.12',
#     'start': 1404,
#     'end': 1431},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.12',
#     'start': 1437,
#     'end': 1463},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.12',
#     'start': 1469,
#     'end': 1493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.11',
#     'start': 1584,
#     'end': 1608},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.11',
#     'start': 1614,
#     'end': 1641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.11',
#     'start': 1647,
#     'end': 1673},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.11',
#     'start': 1679,
#     'end': 1703},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.10',
#     'start': 1794,
#     'end': 1818},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.10',
#     'start': 1824,
#     'end': 1851},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.10',
#     'start': 1857,
#     'end': 1883},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.10',
#     'start': 1889,
#     'end': 1913},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.9',
#     'start': 2003,
#     'end': 2026},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.9',
#     'start': 2032,
#     'end': 2058},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.9',
#     'start': 2064,
#     'end': 2089},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.9',
#     'start': 2095,
#     'end': 2118},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.8',
#     'start': 2208,
#     'end': 2231},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.8',
#     'start': 2237,
#     'end': 2263},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.8',
#     'start': 2269,
#     'end': 2294},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.8',
#     'start': 2300,
#     'end': 2323},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.7',
#     'start': 2413,
#     'end': 2436},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.7',
#     'start': 2442,
#     'end': 2468},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.7',
#     'start': 2474,
#     'end': 2499},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.7',
#     'start': 2505,
#     'end': 2528},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.6',
#     'start': 2618,
#     'end': 2641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.6',
#     'start': 2647,
#     'end': 2673},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.6',
#     'start': 2679,
#     'end': 2704},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.6',
#     'start': 2710,
#     'end': 2733},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.5',
#     'start': 2823,
#     'end': 2846},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.5',
#     'start': 2852,
#     'end': 2878},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.5',
#     'start': 2884,
#     'end': 2909},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.5',
#     'start': 2915,
#     'end': 2938},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.4',
#     'start': 3028,
#     'end': 3051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.4',
#     'start': 3057,
#     'end': 3083},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.4',
#     'start': 3089,
#     'end': 3114},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.4',
#     'start': 3120,
#     'end': 3143},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.3',
#     'start': 3233,
#     'end': 3256},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.3',
#     'start': 3262,
#     'end': 3288},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.3',
#     'start': 3294,
#     'end': 3319},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.3',
#     'start': 3325,
#     'end': 3348},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.2',
#     'start': 3438,
#     'end': 3461},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.2',
#     'start': 3467,
#     'end': 3493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.2',
#     'start': 3499,
#     'end': 3524},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.2',
#     'start': 3530,
#     'end': 3553},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.1',
#     'start': 3643,
#     'end': 3666},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.1',
#     'start': 3672,
#     'end': 3698},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.1',
#     'start': 3704,
#     'end': 3729},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.1',
#     'start': 3735,
#     'end': 3758},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.0',
#     'start': 3868,
#     'end': 3891},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.0',
#     'start': 3897,
#     'end': 3923},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.0',
#     'start': 3929,
#     'end': 3954},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.0',
#     'start': 3960,
#     'end': 3983},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.6',
#     'start': 4073,
#     'end': 4096},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.6',
#     'start': 4102,
#     'end': 4128},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.6',
#     'start': 4134,
#     'end': 4159},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.6',
#     'start': 4165,
#     'end': 4188},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.5',
#     'start': 4278,
#     'end': 4301},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.5',
#     'start': 4307,
#     'end': 4333},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.5',
#     'start': 4339,
#     'end': 4364},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.5',
#     'start': 4370,
#     'end': 4393},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.4',
#     'start': 4483,
#     'end': 4506},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.4',
#     'start': 4512,
#     'end': 4538},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.4',
#     'start': 4544,
#     'end': 4569},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.4',
#     'start': 4575,
#     'end': 4598},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.3',
#     'start': 4688,
#     'end': 4711},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.3',
#     'start': 4717,
#     'end': 4743},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.3',
#     'start': 4749,
#     'end': 4774},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.3',
#     'start': 4780,
#     'end': 4803},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.2',
#     'start': 4893,
#     'end': 4916},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.2',
#     'start': 4922,
#     'end': 4948},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.2',
#     'start': 4954,
#     'end': 4979},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.2',
#     'start': 4985,
#     'end': 5008},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.1',
#     'start': 5098,
#     'end': 5121},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.1',
#     'start': 5127,
#     'end': 5153},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.1',
#     'start': 5159,
#     'end': 5184},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.1',
#     'start': 5190,
#     'end': 5213},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.0',
#     'start': 5323,
#     'end': 5346},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.0',
#     'start': 5352,
#     'end': 5378},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.0',
#     'start': 5384,
#     'end': 5409},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.0',
#     'start': 5415,
#     'end': 5438},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.4.0',
#     'start': 5554,
#     'end': 5577},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.4.0',
#     'start': 5583,
#     'end': 5609},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.4.0',
#     'start': 5615,
#     'end': 5640},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.4.0',
#     'start': 5646,
#     'end': 5669},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.3.1',
#     'start': 5765,
#     'end': 5788},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.3.1',
#     'start': 5794,
#     'end': 5820},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.3.1',
#     'start': 5826,
#     'end': 5851},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.3.1',
#     'start': 5857,
#     'end': 5880},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.3.0',
#     'start': 5996,
#     'end': 6019},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.3.0',
#     'start': 6025,
#     'end': 6051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.3.0',
#     'start': 6057,
#     'end': 6082},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.3.0',
#     'start': 6088,
#     'end': 6111},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.2.1',
#     'start': 6207,
#     'end': 6230},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.2.1',
#     'start': 6236,
#     'end': 6262},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.2.1',
#     'start': 6268,
#     'end': 6293},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.2.1',
#     'start': 6299,
#     'end': 6322},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.2.0',
#     'start': 6438,
#     'end': 6461},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.2.0',
#     'start': 6467,
#     'end': 6493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.2.0',
#     'start': 6499,
#     'end': 6524},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.2.0',
#     'start': 6530,
#     'end': 6553},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.1.1',
#     'start': 6649,
#     'end': 6672},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.1.1',
#     'start': 6678,
#     'end': 6704},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.1.1',
#     'start': 6710,
#     'end': 6735},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.1.1',
#     'start': 6741,
#     'end': 6764},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.1.0',
#     'start': 6880,
#     'end': 6903},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.1.0',
#     'start': 6909,
#     'end': 6935},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.1.0',
#     'start': 6941,
#     'end': 6966},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.1.0',
#     'start': 6972,
#     'end': 6995},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.6',
#     'start': 7091,
#     'end': 7114},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.6',
#     'start': 7120,
#     'end': 7146},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.6',
#     'start': 7152,
#     'end': 7177},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.6',
#     'start': 7183,
#     'end': 7206},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.5',
#     'start': 7302,
#     'end': 7325},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.5',
#     'start': 7331,
#     'end': 7357},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.5',
#     'start': 7363,
#     'end': 7388},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.5',
#     'start': 7394,
#     'end': 7417},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.4',
#     'start': 7513,
#     'end': 7536},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.4',
#     'start': 7542,
#     'end': 7568},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.4',
#     'start': 7574,
#     'end': 7599},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.4',
#     'start': 7605,
#     'end': 7628},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.3',
#     'start': 7725,
#     'end': 7748},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.3',
#     'start': 7754,
#     'end': 7780},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.3',
#     'start': 7786,
#     'end': 7811},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.3',
#     'start': 7817,
#     'end': 7840},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.2',
#     'start': 7939,
#     'end': 7962},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.2',
#     'start': 7968,
#     'end': 7994},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.2',
#     'start': 8000,
#     'end': 8025},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.2',
#     'start': 8031,
#     'end': 8054},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.1',
#     'start': 8178,
#     'end': 8201},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.1',
#     'start': 8207,
#     'end': 8233},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.1',
#     'start': 8239,
#     'end': 8264},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.1',
#     'start': 8270,
#     'end': 8293},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.0',
#     'start': 8517,
#     'end': 8540},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.0',
#     'start': 8546,
#     'end': 8572},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.0',
#     'start': 8578,
#     'end': 8603},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.0',
#     'start': 8609,
#     'end': 8632},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.12',
#     'start': 8753,
#     'end': 8777},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.12',
#     'start': 8783,
#     'end': 8810},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.12',
#     'start': 8816,
#     'end': 8842},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.12',
#     'start': 8848,
#     'end': 8872},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.11',
#     'start': 8974,
#     'end': 8998},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.11',
#     'start': 9004,
#     'end': 9031},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.11',
#     'start': 9037,
#     'end': 9063},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.11',
#     'start': 9069,
#     'end': 9093},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.10',
#     'start': 9195,
#     'end': 9219},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.10',
#     'start': 9225,
#     'end': 9252},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.10',
#     'start': 9258,
#     'end': 9284},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.10',
#     'start': 9290,
#     'end': 9314},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.9',
#     'start': 9415,
#     'end': 9438},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.9',
#     'start': 9444,
#     'end': 9470},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.9',
#     'start': 9476,
#     'end': 9501},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.9',
#     'start': 9507,
#     'end': 9530},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.8',
#     'start': 9699,
#     'end': 9722},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.8',
#     'start': 9728,
#     'end': 9754},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.8',
#     'start': 9760,
#     'end': 9785},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.8',
#     'start': 9791,
#     'end': 9814},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.7',
#     'start': 9915,
#     'end': 9938},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.7',
#     'start': 9944,
#     'end': 9970},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.7',
#     'start': 9976,
#     'end': 10001},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.7',
#     'start': 10007,
#     'end': 10030},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.6',
#     'start': 10131,
#     'end': 10154},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.6',
#     'start': 10160,
#     'end': 10186},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.6',
#     'start': 10192,
#     'end': 10217},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.6',
#     'start': 10223,
#     'end': 10246},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.5',
#     'start': 10347,
#     'end': 10370},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.5',
#     'start': 10376,
#     'end': 10402},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.5',
#     'start': 10408,
#     'end': 10433},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.5',
#     'start': 10439,
#     'end': 10462},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.4',
#     'start': 10563,
#     'end': 10586},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.4',
#     'start': 10592,
#     'end': 10618},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.4',
#     'start': 10624,
#     'end': 10649},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.4',
#     'start': 10655,
#     'end': 10678},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.3',
#     'start': 10779,
#     'end': 10802},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.3',
#     'start': 10808,
#     'end': 10834},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.3',
#     'start': 10840,
#     'end': 10865},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.3',
#     'start': 10871,
#     'end': 10894},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.2',
#     'start': 10995,
#     'end': 11018},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.2',
#     'start': 11024,
#     'end': 11050},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.2',
#     'start': 11056,
#     'end': 11081},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.2',
#     'start': 11087,
#     'end': 11110},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.1',
#     'start': 11341,
#     'end': 11364},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.1',
#     'start': 11370,
#     'end': 11396},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.1',
#     'start': 11402,
#     'end': 11427},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.1',
#     'start': 11433,
#     'end': 11456},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@0.0.1',
#     'start': 11692,
#     'end': 11715},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@0.0.1',
#     'start': 11721,
#     'end': 11747},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@0.0.1',
#     'start': 11753,
#     'end': 11778},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@0.0.1',
#     'start': 11784,
#     'end': 11807},
#    {'tag': 'KEY', 'value': 'f47dbc9c:', 'start': 879, 'end': 888},
#    {'tag': 'KEY', 'value': 'bf08b6df:', 'start': 5041, 'end': 5050},
#    {'tag': 'KEY', 'value': '9fa40eb7:', 'start': 9847, 'end': 9856},
#    {'tag': 'KEY', 'value': 'dc22a3aa:', 'start': 10063, 'end': 10072},
#    {'tag': 'KEY', 'value': '2b3bda0b:', 'start': 11520, 'end': 11529}]},
#  {'index': 7,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443},
#    {'tag': 'EMAIL', 'value': 'info@srampos.com', 'start': 195, 'end': 211},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.5',
#     'start': 116,
#     'end': 139},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.5',
#     'start': 145,
#     'end': 171},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.5',
#     'start': 177,
#     'end': 202},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.5',
#     'start': 208,
#     'end': 231},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.4',
#     'start': 321,
#     'end': 344},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.4',
#     'start': 350,
#     'end': 376},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.4',
#     'start': 382,
#     'end': 407},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.4',
#     'start': 413,
#     'end': 436},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.3',
#     'start': 526,
#     'end': 549},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.3',
#     'start': 555,
#     'end': 581},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.3',
#     'start': 587,
#     'end': 612},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.3',
#     'start': 618,
#     'end': 641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.2',
#     'start': 731,
#     'end': 754},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.2',
#     'start': 760,
#     'end': 786},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.2',
#     'start': 792,
#     'end': 817},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.2',
#     'start': 823,
#     'end': 846},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.1',
#     'start': 936,
#     'end': 959},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.1',
#     'start': 965,
#     'end': 991},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.1',
#     'start': 997,
#     'end': 1022},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.1',
#     'start': 1028,
#     'end': 1051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.0',
#     'start': 1161,
#     'end': 1184},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.0',
#     'start': 1190,
#     'end': 1216},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.0',
#     'start': 1222,
#     'end': 1247},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.0',
#     'start': 1253,
#     'end': 1276},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.12',
#     'start': 1374,
#     'end': 1398},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.12',
#     'start': 1404,
#     'end': 1431},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.12',
#     'start': 1437,
#     'end': 1463},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.12',
#     'start': 1469,
#     'end': 1493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.11',
#     'start': 1584,
#     'end': 1608},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.11',
#     'start': 1614,
#     'end': 1641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.11',
#     'start': 1647,
#     'end': 1673},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.11',
#     'start': 1679,
#     'end': 1703},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.10',
#     'start': 1794,
#     'end': 1818},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.10',
#     'start': 1824,
#     'end': 1851},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.10',
#     'start': 1857,
#     'end': 1883},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.10',
#     'start': 1889,
#     'end': 1913},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.9',
#     'start': 2003,
#     'end': 2026},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.9',
#     'start': 2032,
#     'end': 2058},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.9',
#     'start': 2064,
#     'end': 2089},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.9',
#     'start': 2095,
#     'end': 2118},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.8',
#     'start': 2208,
#     'end': 2231},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.8',
#     'start': 2237,
#     'end': 2263},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.8',
#     'start': 2269,
#     'end': 2294},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.8',
#     'start': 2300,
#     'end': 2323},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.7',
#     'start': 2413,
#     'end': 2436},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.7',
#     'start': 2442,
#     'end': 2468},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.7',
#     'start': 2474,
#     'end': 2499},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.7',
#     'start': 2505,
#     'end': 2528},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.6',
#     'start': 2618,
#     'end': 2641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.6',
#     'start': 2647,
#     'end': 2673},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.6',
#     'start': 2679,
#     'end': 2704},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.6',
#     'start': 2710,
#     'end': 2733},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.5',
#     'start': 2823,
#     'end': 2846},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.5',
#     'start': 2852,
#     'end': 2878},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.5',
#     'start': 2884,
#     'end': 2909},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.5',
#     'start': 2915,
#     'end': 2938},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.4',
#     'start': 3028,
#     'end': 3051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.4',
#     'start': 3057,
#     'end': 3083},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.4',
#     'start': 3089,
#     'end': 3114},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.4',
#     'start': 3120,
#     'end': 3143},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.3',
#     'start': 3233,
#     'end': 3256},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.3',
#     'start': 3262,
#     'end': 3288},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.3',
#     'start': 3294,
#     'end': 3319},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.3',
#     'start': 3325,
#     'end': 3348},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.2',
#     'start': 3438,
#     'end': 3461},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.2',
#     'start': 3467,
#     'end': 3493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.2',
#     'start': 3499,
#     'end': 3524},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.2',
#     'start': 3530,
#     'end': 3553},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.1',
#     'start': 3643,
#     'end': 3666},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.1',
#     'start': 3672,
#     'end': 3698},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.1',
#     'start': 3704,
#     'end': 3729},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.1',
#     'start': 3735,
#     'end': 3758},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.6.0',
#     'start': 3868,
#     'end': 3891},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.6.0',
#     'start': 3897,
#     'end': 3923},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.6.0',
#     'start': 3929,
#     'end': 3954},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.6.0',
#     'start': 3960,
#     'end': 3983},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.6',
#     'start': 4073,
#     'end': 4096},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.6',
#     'start': 4102,
#     'end': 4128},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.6',
#     'start': 4134,
#     'end': 4159},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.6',
#     'start': 4165,
#     'end': 4188},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.5',
#     'start': 4278,
#     'end': 4301},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.5',
#     'start': 4307,
#     'end': 4333},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.5',
#     'start': 4339,
#     'end': 4364},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.5',
#     'start': 4370,
#     'end': 4393},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.4',
#     'start': 4483,
#     'end': 4506},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.4',
#     'start': 4512,
#     'end': 4538},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.4',
#     'start': 4544,
#     'end': 4569},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.4',
#     'start': 4575,
#     'end': 4598},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.3',
#     'start': 4688,
#     'end': 4711},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.3',
#     'start': 4717,
#     'end': 4743},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.3',
#     'start': 4749,
#     'end': 4774},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.3',
#     'start': 4780,
#     'end': 4803},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.2',
#     'start': 4893,
#     'end': 4916},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.2',
#     'start': 4922,
#     'end': 4948},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.2',
#     'start': 4954,
#     'end': 4979},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.2',
#     'start': 4985,
#     'end': 5008},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.1',
#     'start': 5098,
#     'end': 5121},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.1',
#     'start': 5127,
#     'end': 5153},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.1',
#     'start': 5159,
#     'end': 5184},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.1',
#     'start': 5190,
#     'end': 5213},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.5.0',
#     'start': 5323,
#     'end': 5346},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.5.0',
#     'start': 5352,
#     'end': 5378},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.5.0',
#     'start': 5384,
#     'end': 5409},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.5.0',
#     'start': 5415,
#     'end': 5438},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.4.0',
#     'start': 5554,
#     'end': 5577},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.4.0',
#     'start': 5583,
#     'end': 5609},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.4.0',
#     'start': 5615,
#     'end': 5640},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.4.0',
#     'start': 5646,
#     'end': 5669},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.3.1',
#     'start': 5765,
#     'end': 5788},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.3.1',
#     'start': 5794,
#     'end': 5820},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.3.1',
#     'start': 5826,
#     'end': 5851},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.3.1',
#     'start': 5857,
#     'end': 5880},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.3.0',
#     'start': 5996,
#     'end': 6019},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.3.0',
#     'start': 6025,
#     'end': 6051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.3.0',
#     'start': 6057,
#     'end': 6082},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.3.0',
#     'start': 6088,
#     'end': 6111},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.2.1',
#     'start': 6207,
#     'end': 6230},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.2.1',
#     'start': 6236,
#     'end': 6262},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.2.1',
#     'start': 6268,
#     'end': 6293},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.2.1',
#     'start': 6299,
#     'end': 6322},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.2.0',
#     'start': 6438,
#     'end': 6461},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.2.0',
#     'start': 6467,
#     'end': 6493},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.2.0',
#     'start': 6499,
#     'end': 6524},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.2.0',
#     'start': 6530,
#     'end': 6553},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.1.1',
#     'start': 6649,
#     'end': 6672},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.1.1',
#     'start': 6678,
#     'end': 6704},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.1.1',
#     'start': 6710,
#     'end': 6735},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.1.1',
#     'start': 6741,
#     'end': 6764},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.1.0',
#     'start': 6880,
#     'end': 6903},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.1.0',
#     'start': 6909,
#     'end': 6935},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.1.0',
#     'start': 6941,
#     'end': 6966},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.1.0',
#     'start': 6972,
#     'end': 6995},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.6',
#     'start': 7091,
#     'end': 7114},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.6',
#     'start': 7120,
#     'end': 7146},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.6',
#     'start': 7152,
#     'end': 7177},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.6',
#     'start': 7183,
#     'end': 7206},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.5',
#     'start': 7302,
#     'end': 7325},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.5',
#     'start': 7331,
#     'end': 7357},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.5',
#     'start': 7363,
#     'end': 7388},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.5',
#     'start': 7394,
#     'end': 7417},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.4',
#     'start': 7513,
#     'end': 7536},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.4',
#     'start': 7542,
#     'end': 7568},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.4',
#     'start': 7574,
#     'end': 7599},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.4',
#     'start': 7605,
#     'end': 7628},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.3',
#     'start': 7725,
#     'end': 7748},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.3',
#     'start': 7754,
#     'end': 7780},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.3',
#     'start': 7786,
#     'end': 7811},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.3',
#     'start': 7817,
#     'end': 7840},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.2',
#     'start': 7939,
#     'end': 7962},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.2',
#     'start': 7968,
#     'end': 7994},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.2',
#     'start': 8000,
#     'end': 8025},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.2',
#     'start': 8031,
#     'end': 8054},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.1',
#     'start': 8178,
#     'end': 8201},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.1',
#     'start': 8207,
#     'end': 8233},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.1',
#     'start': 8239,
#     'end': 8264},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.1',
#     'start': 8270,
#     'end': 8293},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@4.0.0',
#     'start': 8517,
#     'end': 8540},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@4.0.0',
#     'start': 8546,
#     'end': 8572},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@4.0.0',
#     'start': 8578,
#     'end': 8603},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@4.0.0',
#     'start': 8609,
#     'end': 8632},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.12',
#     'start': 8753,
#     'end': 8777},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.12',
#     'start': 8783,
#     'end': 8810},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.12',
#     'start': 8816,
#     'end': 8842},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.12',
#     'start': 8848,
#     'end': 8872},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.11',
#     'start': 8974,
#     'end': 8998},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.11',
#     'start': 9004,
#     'end': 9031},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.11',
#     'start': 9037,
#     'end': 9063},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.11',
#     'start': 9069,
#     'end': 9093},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.10',
#     'start': 9195,
#     'end': 9219},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.10',
#     'start': 9225,
#     'end': 9252},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.10',
#     'start': 9258,
#     'end': 9284},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.10',
#     'start': 9290,
#     'end': 9314},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.9',
#     'start': 9415,
#     'end': 9438},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.9',
#     'start': 9444,
#     'end': 9470},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.9',
#     'start': 9476,
#     'end': 9501},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.9',
#     'start': 9507,
#     'end': 9530},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.8',
#     'start': 9699,
#     'end': 9722},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.8',
#     'start': 9728,
#     'end': 9754},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.8',
#     'start': 9760,
#     'end': 9785},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.8',
#     'start': 9791,
#     'end': 9814},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.7',
#     'start': 9915,
#     'end': 9938},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.7',
#     'start': 9944,
#     'end': 9970},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.7',
#     'start': 9976,
#     'end': 10001},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.7',
#     'start': 10007,
#     'end': 10030},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.6',
#     'start': 10131,
#     'end': 10154},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.6',
#     'start': 10160,
#     'end': 10186},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.6',
#     'start': 10192,
#     'end': 10217},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.6',
#     'start': 10223,
#     'end': 10246},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.5',
#     'start': 10347,
#     'end': 10370},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.5',
#     'start': 10376,
#     'end': 10402},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.5',
#     'start': 10408,
#     'end': 10433},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.5',
#     'start': 10439,
#     'end': 10462},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.4',
#     'start': 10563,
#     'end': 10586},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.4',
#     'start': 10592,
#     'end': 10618},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.4',
#     'start': 10624,
#     'end': 10649},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.4',
#     'start': 10655,
#     'end': 10678},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.3',
#     'start': 10779,
#     'end': 10802},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.3',
#     'start': 10808,
#     'end': 10834},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.3',
#     'start': 10840,
#     'end': 10865},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.3',
#     'start': 10871,
#     'end': 10894},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.2',
#     'start': 10995,
#     'end': 11018},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.2',
#     'start': 11024,
#     'end': 11050},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.2',
#     'start': 11056,
#     'end': 11081},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.2',
#     'start': 11087,
#     'end': 11110},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.1',
#     'start': 11341,
#     'end': 11364},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.1',
#     'start': 11370,
#     'end': 11396},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.1',
#     'start': 11402,
#     'end': 11427},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.1',
#     'start': 11433,
#     'end': 11456},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@0.0.1',
#     'start': 11692,
#     'end': 11715},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@0.0.1',
#     'start': 11721,
#     'end': 11747},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@0.0.1',
#     'start': 11753,
#     'end': 11778},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@0.0.1',
#     'start': 11784,
#     'end': 11807},
#    {'tag': 'KEY', 'value': 'f47dbc9c:', 'start': 879, 'end': 888},
#    {'tag': 'KEY', 'value': 'bf08b6df:', 'start': 5041, 'end': 5050},
#    {'tag': 'KEY', 'value': '9fa40eb7:', 'start': 9847, 'end': 9856},
#    {'tag': 'KEY', 'value': 'dc22a3aa:', 'start': 10063, 'end': 10072},
#    {'tag': 'KEY', 'value': '2b3bda0b:', 'start': 11520, 'end': 11529},
#    {'tag': 'EMAIL',
#     'value': '<liu21st@gmail.com>',
#     'start': 502,
#     'end': 521}]},
#  {'index': 8,
#   'secrets': [{'tag': 'EMAIL',
#     'value': 'davis@dlib.net',
#     'start': 38,
#     'end': 52},
#    {'tag': 'KEY',
#     'value': '3CD5FCBC8EAD4E0A80FA41A62',
#     'start': 3504,
#     'end': 3529},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1797,
#     'end': 1817},
#    {'tag': 'EMAIL',
#     'value': 'nugetvss@microsoft.com',
#     'start': 421,
#     'end': 443},
#    {'tag': 'EMAIL', 'value': 'info@srampos.com', 'start': 195, 'end': 211},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.5',
#     'start': 116,
#     'end': 139},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.5',
#     'start': 145,
#     'end': 171},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.5',
#     'start': 177,
#     'end': 202},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.5',
#     'start': 208,
#     'end': 231},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.4',
#     'start': 321,
#     'end': 344},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.4',
#     'start': 350,
#     'end': 376},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.4',
#     'start': 382,
#     'end': 407},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.4',
#     'start': 413,
#     'end': 436},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.3',
#     'start': 526,
#     'end': 549},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.3',
#     'start': 555,
#     'end': 581},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.3',
#     'start': 587,
#     'end': 612},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.3',
#     'start': 618,
#     'end': 641},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.2',
#     'start': 731,
#     'end': 754},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.2',
#     'start': 760,
#     'end': 786},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.2',
#     'start': 792,
#     'end': 817},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.2',
#     'start': 823,
#     'end': 846},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.1',
#     'start': 936,
#     'end': 959},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.1',
#     'start': 965,
#     'end': 991},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@5.0.1',
#     'start': 997,
#     'end': 1022},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@5.0.1',
#     'start': 1028,
#     'end': 1051},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@5.0.0',
#     'start': 1161,
#     'end': 1184},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@5.0.0',
#     'start': 1190,
#     'end': 1216},
#    {'tag': 'EMAIL',
# ...
#     'value': 'dusk-network/button@3.0.5',
#     'start': 10408,
#     'end': 10433},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.5',
#     'start': 10439,
#     'end': 10462},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.4',
#     'start': 10563,
#     'end': 10586},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.4',
#     'start': 10592,
#     'end': 10618},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.4',
#     'start': 10624,
#     'end': 10649},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.4',
#     'start': 10655,
#     'end': 10678},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.3',
#     'start': 10779,
#     'end': 10802},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.3',
#     'start': 10808,
#     'end': 10834},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.3',
#     'start': 10840,
#     'end': 10865},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.3',
#     'start': 10871,
#     'end': 10894},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.2',
#     'start': 10995,
#     'end': 11018},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.2',
#     'start': 11024,
#     'end': 11050},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.2',
#     'start': 11056,
#     'end': 11081},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.2',
#     'start': 11087,
#     'end': 11110},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@3.0.1',
#     'start': 11341,
#     'end': 11364},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@3.0.1',
#     'start': 11370,
#     'end': 11396},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@3.0.1',
#     'start': 11402,
#     'end': 11427},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@3.0.1',
#     'start': 11433,
#     'end': 11456},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/icon@0.0.1',
#     'start': 11692,
#     'end': 11715},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/helpers@0.0.1',
#     'start': 11721,
#     'end': 11747},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/button@0.0.1',
#     'start': 11753,
#     'end': 11778},
#    {'tag': 'EMAIL',
#     'value': 'dusk-network/menu@0.0.1',
#     'start': 11784,
#     'end': 11807},
#    {'tag': 'KEY', 'value': 'f47dbc9c:', 'start': 879, 'end': 888},
#    {'tag': 'KEY', 'value': 'bf08b6df:', 'start': 5041, 'end': 5050},
#    {'tag': 'KEY', 'value': '9fa40eb7:', 'start': 9847, 'end': 9856},
#    {'tag': 'KEY', 'value': 'dc22a3aa:', 'start': 10063, 'end': 10072},
#    {'tag': 'KEY', 'value': '2b3bda0b:', 'start': 11520, 'end': 11529},
#    {'tag': 'EMAIL', 'value': '<liu21st@gmail.com>', 'start': 502, 'end': 521},
#    {'tag': 'EMAIL',
#     'value': '<beat-kueng@gmx.net>',
#     'start': 1819,
#     'end': 1839},
#    {'tag': 'EMAIL', 'value': 'porten@kde.org', 'start': 606, 'end': 620},
#    {'tag': 'EMAIL', 'value': 'pmk@post.com', 'start': 658, 'end': 670},
#    {'tag': 'EMAIL',
#     'value': 'cwzwarich@uwaterloo.ca',
#     'start': 803,
#     'end': 825},
#    {'tag': 'EMAIL',
#     'value': 'kohsuke.kawaguchi@sun.com',
#     'start': 1766,
#     'end': 1791},
#    {'tag': 'EMAIL', 'value': '<will@thames.id.au>', 'start': 61, 'end': 80},
#    {'tag': 'EMAIL', 'value': '{benyuwan@gmail.com}', 'start': 15, 'end': 35},
#    {'tag': 'EMAIL',
#     'value': 'andreas@wellenvogel.net',
#     'start': 172,
#     'end': 195},
#    {'tag': 'IP_ADDRESS', 'value': '72.44.36.12', 'start': 1193, 'end': 1204},
#    {'tag': 'IP_ADDRESS', 'value': '72.44.36.12', 'start': 1289, 'end': 1300},
#    {'tag': 'IP_ADDRESS', 'value': '72.44.36.12', 'start': 1336, 'end': 1347},
#    {'tag': 'EMAIL',
#     'value': 'test.satou@example.com',
#     'start': 1338,
#     'end': 1360},
#    {'tag': 'EMAIL',
#     'value': '//deno.land/std@0.142.0/testing/asserts.ts',
#     'start': 21,
#     'end': 63},
#    {'tag': 'KEY',
#     'value': 'runs:/96771d893a5e46159d9f3b49bf9013e2',
#     'start': 21061,
#     'end': 21099},
#    {'tag': 'EMAIL',
#     'value': '<nicolas.george@normalesup.org>',
#     'start': 40,
#     'end': 71},
#    {'tag': 'IP_ADDRESS',
#     'value': '255.255.255.255',
#     'start': 2035,
#     'end': 2050},
#    {'tag': 'IP_ADDRESS', 'value': '255.255.255.0', 'start': 5059, 'end': 5072},
#    {'tag': 'EMAIL', 'value': 'user@test.com', 'start': 797, 'end': 810},
#    {'tag': 'EMAIL', 'value': 'user@test.com', 'start': 936, 'end': 949},
#    {'tag': 'EMAIL', 'value': 'user1@test.com', 'start': 1086, 'end': 1100},
#    {'tag': 'EMAIL', 'value': 'user1@test.com', 'start': 1240, 'end': 1254},
#    {'tag': 'KEY',
#     'value': 'id=0Bz8a_Dbh9QhbaW12WVVZS2drcnM',
#     'start': 385,
#     'end': 416},
#    {'tag': 'EMAIL', 'value': 'jfinal@126.com', 'start': 48, 'end': 62},
#    {'tag': 'KEY',
#     'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9',
#     'start': 276,
#     'end': 312},
#    {'tag': 'KEY',
#     'value': 'eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ',
#     'start': 313,
#     'end': 467},
#    {'tag': 'KEY',
#     'value': 'D8ja66bnLxJ3bsJlaKRtOquu8XbibjNCyFxJpI7vafc',
#     'start': 468,
#     'end': 511},
#    {'tag': 'KEY',
#     'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9',
#     'start': 694,
#     'end': 730},
#    {'tag': 'KEY',
#     'value': 'eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ',
#     'start': 731,
#     'end': 885},
#    {'tag': 'KEY',
#     'value': '8X-fBRUHdrwtkTLcOFAsW-vvvqCzmkZKM2gQgHNkBKk',
#     'start': 886,
#     'end': 929},
#    {'tag': 'IP_ADDRESS', 'value': '0.0.0.0', 'start': 163, 'end': 170},
#    {'tag': 'IP_ADDRESS', 'value': '162.243.201.175', 'start': 571, 'end': 586},
#    {'tag': 'IP_ADDRESS', 'value': '1.3.6.1', 'start': 1023, 'end': 1030},
#    {'tag': 'IP_ADDRESS', 'value': '1.1.2.9', 'start': 1040, 'end': 1047},
#    {'tag': 'IP_ADDRESS', 'value': '1.3.6.1', 'start': 1172, 'end': 1179},
#    {'tag': 'IP_ADDRESS', 'value': '1.1.2.9', 'start': 1189, 'end': 1196},
#    {'tag': 'EMAIL',
#     'value': 'david@reciprocitylabs.com',
#     'start': 172,
#     'end': 197},
#    {'tag': 'EMAIL',
#     'value': 'david@reciprocitylabs.com',
#     'start': 215,
#     'end': 240},
#    {'tag': 'EMAIL', 'value': 'f.miir117@gmail.com', 'start': 30, 'end': 49},
#    {'tag': 'KEY',
#     'value': '6acfd1f8d238bc5d25d97d2c9e6f6b177699389a',
#     'start': 7874,
#     'end': 7914},
#    {'tag': 'KEY',
#     'value': 'cb2f8b691ccf3eae9846c67735f413a49befea28',
#     'start': 11440,
#     'end': 11480},
#    {'tag': 'EMAIL',
#     'value': '`@declarative`.\\n\\tBecause',
#     'start': 15686,
#     'end': 15712},
#    {'tag': 'IP_ADDRESS', 'value': '146.110.60.20', 'start': 353, 'end': 366},
#    {'tag': 'KEY',
#     'value': '7555e8e24958cae4cfd197135950359b9fe8373d4862a03677f089d215119a3a',
#     'start': 6052,
#     'end': 6116},
#    {'tag': 'IP_ADDRESS', 'value': '1.2.10.1', 'start': 31, 'end': 39},
#    {'tag': 'IP_ADDRESS', 'value': '1.2.10.1', 'start': 2086, 'end': 2094},
#    {'tag': 'IP_ADDRESS', 'value': '6.0.0.0', 'start': 325, 'end': 332},
#    {'tag': 'IP_ADDRESS', 'value': '6.0.0.0', 'start': 545, 'end': 552},
#    {'tag': 'IP_ADDRESS', 'value': '6.0.0.0', 'start': 765, 'end': 772},
#    {'tag': 'IP_ADDRESS', 'value': '6.0.0.0', 'start': 971, 'end': 978},
#    {'tag': 'EMAIL',
#     'value': '<diego.sueiro@gmail.com>',
#     'start': 39,
#     'end': 63},
#    {'tag': 'IP_ADDRESS', 'value': '121.14.110.200', 'start': 430, 'end': 444},
#    {'tag': 'IP_ADDRESS', 'value': '0.0.0.0', 'start': 42191, 'end': 42198},
#    {'tag': 'EMAIL',
#     'value': 'imre.leber@worldonline.be',
#     'start': 877,
#     'end': 902},
#    {'tag': 'EMAIL',
#     'value': '<qiang.xue@gmail.com>',
#     'start': 263,
#     'end': 284},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.1.1', 'start': 387, 'end': 394},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.1.2', 'start': 697, 'end': 704},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.1.3', 'start': 1332, 'end': 1339},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.2.1', 'start': 2574, 'end': 2581},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.2.2', 'start': 2971, 'end': 2978},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.2.3', 'start': 3339, 'end': 3346},
#    {'tag': 'IP_ADDRESS', 'value': '4.1.2.4', 'start': 4389, 'end': 4396},
#    {'tag': 'KEY',
#     'value': '7bf5d19f-560a-42f0-9a61-a1b19aca3e69',
#     'start': 1089,
#     'end': 1125},
#    {'tag': 'IP_ADDRESS', 'value': '1.1.0.0', 'start': 1529, 'end': 1536},
#    {'tag': 'EMAIL',
#     'value': '<tim.schneider@northbridge-development.de>',
#     'start': 90,
#     'end': 132},
#    {'tag': 'EMAIL',
#     'value': 'mail@northbridge-development.de',
#     'start': 295,
#     'end': 326},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 1168, 'end': 1186},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 1662, 'end': 1680},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 13081, 'end': 13099},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 13352, 'end': 13370},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 14261, 'end': 14279},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 16151, 'end': 16169},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 16668, 'end': 16686},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 17130, 'end': 17148},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 20966, 'end': 20984},
#    {'tag': 'KEY', 'value': 'zmq::pgm_socket_t:', 'start': 21713, 'end': 21731},
#    {'tag': 'IP_ADDRESS', 'value': '239.192.0.1', 'start': 1551, 'end': 1562},
#    {'tag': 'IP_ADDRESS', 'value': '224.250.0.1', 'start': 1588, 'end': 1599},
#    {'tag': 'IP_ADDRESS', 'value': '224.250.0.3', 'start': 1612, 'end': 1623},
#    {'tag': 'KEY',
#     'value': '27dcfe42e3fb3422b72ce48b48bf601c0a3e46e850ee72d9bdd17b5863b6e42c',
#     'start': 1285,
#     'end': 1349},
#    {'tag': 'KEY',
#     'value': '85b978995b67db0b1a12dd1a73b09ef3d39f8e3cb09f8b9c60cf04633acce46c',
#     'start': 1772,
#     'end': 1836},
#    {'tag': 'KEY',
#     'value': 'ac16bed9cdd3c63bca1fe1ac3de522a1376b1487c4fc85b7b19592e28fd98e26',
#     'start': 1966,
#     'end': 2030},
#    {'tag': 'KEY',
#     'value': 'd11f091ed54c56c325ffca1083113a405fcd8a25d5888af64f5cd6cf587b7b0a',
#     'start': 2451,
#     'end': 2515},
#    {'tag': 'KEY',
#     'value': '9fb572daef35a1c8608d1a6232a4a9f56846bab2854c50562dfb9a7be294f4e8',
#     'start': 2645,
#     'end': 2709},
#    {'tag': 'EMAIL',
#     'value': 'intersight@cisco.com',
#     'start': 1716,
#     'end': 1736},
#    {'tag': 'EMAIL', 'value': 'thamelry@binf.ku.dk', 'start': 40, 'end': 59},
#    {'tag': 'EMAIL', 'value': 'roygeesa@gmail.com', 'start': 1136, 'end': 1154},
#    {'tag': 'EMAIL',
#     'value': '>roygeesa@gmail.com</a>',
#     'start': 1155,
#     'end': 1178},
#    {'tag': 'KEY',
#     'value': '0x4Dc71113329d2F4Dbab6eB006C330abD24a2eF0C',
#     'start': 5588,
#     'end': 5630},
#    {'tag': 'EMAIL', 'value': 'zaneadix@gmail.com', 'start': 63, 'end': 81},
#    {'tag': 'KEY',
#     'value': 'h5uuuuui3unn645wejhdjhikjdsf',
#     'start': 9122,
#     'end': 9150},
#    {'tag': 'KEY',
#     'value': '9ecb36561341d18eb65484e833efea61edc74b84cf5e6ae1b81c63533e25fc8f',
#     'start': 15609,
#     'end': 15673},
#    {'tag': 'KEY',
#     'value': '07f8536d-c78f-4af3-b668-3c83d122e6e9',
#     'start': 362,
#     'end': 398},
#    {'tag': 'IP_ADDRESS', 'value': '87.248.113.14', 'start': 2415, 'end': 2428},
#    {'tag': 'IP_ADDRESS', 'value': '87.248.113.14', 'start': 6789, 'end': 6802},
#    {'tag': 'IP_ADDRESS', 'value': '87.248.113.14', 'start': 6881, 'end': 6894},
#    {'tag': 'IP_ADDRESS', 'value': '87.248.113.14', 'start': 6973, 'end': 6986},
#    {'tag': 'IP_ADDRESS', 'value': '87.248.113.14', 'start': 7065, 'end': 7078},
#    {'tag': 'EMAIL', 'value': 'stegu@itn.liu.se', 'start': 237, 'end': 253},
#    {'tag': 'EMAIL', 'value': '1910646@tongji.edu.cn', 'start': 77, 'end': 98},
#    {'tag': 'EMAIL',
#     'value': 'gustavo.valiente@protonmail.com',
#     'start': 42,
#     'end': 73},
#    {'tag': 'EMAIL', 'value': 'scortes3@umd.edu', 'start': 46, 'end': 62},
#    {'tag': 'EMAIL', 'value': 'sameer@umd.edu', 'start': 85, 'end': 99},
#    {'tag': 'EMAIL',
#     'value': 'pkabra@terpmail.umd.edu',
#     'start': 115,
#     'end': 138},
#    {'tag': 'EMAIL',
#     'value': '<david.sehnal@gmail.com>',
#     'start': 231,
#     'end': 255},
#    {'tag': 'EMAIL',
#     'value': '<alexander.rose@weirdbyte.de>',
#     'start': 282,
#     'end': 311},
#    {'tag': 'KEY', 'value': 'g:/test/mdb/xray-1tqn', 'start': 585, 'end': 606},
#    {'tag': 'KEY',
#     'value': 'com/mpr/mpr/shrinknp_800_800/AAEAAQAAAAAAAAc3AAAAJGEzNjRmMWZmLWI3YTgtNGNmYy1hOTU0LTQ0ZDU4ZjgwMDJiZQ',
#     'start': 7069,
#     'end': 7168},
#    {'tag': 'KEY', 'value': 'i7yoq4uE0Kk62bfa', 'start': 12189, 'end': 12205},
#    {'tag': 'KEY', 'value': '-SY5eww-OW9xbMs', 'start': 13558, 'end': 13573},
#    {'tag': 'KEY', 'value': 'be/hT-4pVmkGt0', 'start': 18113, 'end': 18127},
#    {'tag': 'KEY', 'value': '0x0D0A1A0A', 'start': 509, 'end': 519},
#    {'tag': 'EMAIL',
#     'value': 'dehalleux@pelikhan.com',
#     'start': 124,
#     'end': 146},
#    {'tag': 'EMAIL',
#     'value': '//cdn.jsdelivr.net/gh/konpa/devicon@master/devicon.min.css',
#     'start': 319,
#     'end': 377},
#    {'tag': 'EMAIL', 'value': 'babarczi@tmit.bme.hu', 'start': 90, 'end': 110},
#    {'tag': 'EMAIL', 'value': 'support@coinapi.io', 'start': 328, 'end': 346},
#    {'tag': 'EMAIL',
#     'value': '<ljvderijk@gmail.com>',
#     'start': 717,
#     'end': 738},
#    {'tag': 'KEY',
#     'value': 'ga25f3b6123ff5cbf277c4117617980738',
#     'start': 77,
#     'end': 111},
#    {'tag': 'KEY',
#     'value': 'gaae2cb38734654cfeca1d77b0439c243e',
#     'start': 385,
#     'end': 419},
#    {'tag': 'KEY',
#     'value': 'gaf724dbd61d196f9bd1a8060f1f73816d',
#     'start': 480,
#     'end': 514},
#    {'tag': 'KEY',
#     'value': 'ga180a0386c25a456d436bbfc9fec05c02',
#     'start': 582,
#     'end': 616},
#    {'tag': 'KEY',
#     'value': 'ga5ada36b95407b1169e183bbb7b9847d6',
#     'start': 885,
#     'end': 919},
#    {'tag': 'IP_ADDRESS', 'value': '4.0.0.0', 'start': 942, 'end': 949},
#    {'tag': 'EMAIL',
#     'value': '<bigeasy@linutronix.de>',
#     'start': 202,
#     'end': 225},
#    {'tag': 'EMAIL',
#     'value': '`aaron.mcdonald@mailinator.com/password`',
#     'start': 2510,
#     'end': 2550},
#    {'tag': 'KEY',
#     'value': '01a20578-56c3-41b3-8a0e-281104af2481',
#     'start': 344,
#     'end': 380},
#    {'tag': 'IP_ADDRESS', 'value': '192.168.1.1', 'start': 4401, 'end': 4412},
#    {'tag': 'KEY',
#     'value': 'FAIR/20171220/X-101-32x8d',
#     'start': 5401,
#     'end': 5426},
#    {'tag': 'KEY',
#     'value': 'FAIR/20171220/X-101-64x4d',
#     'start': 5485,
#     'end': 5510},
#    {'tag': 'KEY',
#     'value': 'e2e_faster_rcnn_R-50-C4_1x',
#     'start': 5735,
#     'end': 5761},
#    {'tag': 'KEY',
#     'value': 'e2e_faster_rcnn_R-50-FPN_1x',
#     'start': 5803,
#     'end': 5830},
#    {'tag': 'KEY',
#     'value': 'e2e_faster_rcnn_R-101-FPN_1x',
#     'start': 5872,
#     'end': 5900},
#    {'tag': 'KEY',
#     'value': 'e2e_faster_rcnn_X-101-32x8d-FPN_1x',
#     'start': 5942,
#     'end': 5976},
#    {'tag': 'KEY',
#     'value': 'e2e_mask_rcnn_R-50-C4_1x',
#     'start': 6018,
#     'end': 6042},
#    {'tag': 'KEY',
#     'value': 'e2e_mask_rcnn_R-50-FPN_1x',
#     'start': 6084,
#     'end': 6109},
#    {'tag': 'KEY',
#     'value': 'e2e_mask_rcnn_R-101-FPN_1x',
#     'start': 6151,
#     'end': 6177},
#    {'tag': 'KEY',
#     'value': 'e2e_mask_rcnn_X-101-32x8d-FPN_1x',
#     'start': 6219,
#     'end': 6251},
#    {'tag': 'KEY',
#     'value': 'e2e_mask_rcnn_X-152-32x8d-FPN-IN5k_1',
#     'start': 6293,
#     'end': 6329},
#    {'tag': 'KEY',
#     'value': 'e2e_keypoint_rcnn_R-50-FPN_1x',
#     'start': 6395,
#     'end': 6424},
#    {'tag': 'IP_ADDRESS', 'value': '127.0.0.1', 'start': 279, 'end': 288},
#    {'tag': 'IP_ADDRESS', 'value': '127.0.0.1', 'start': 1089, 'end': 1098},
#    {'tag': 'EMAIL', 'value': 'otp@example.com', 'start': 203, 'end': 218},
#    {'tag': 'EMAIL',
#     'value': 'zhengzheng.ge@horizon.ai',
#     'start': 187,
#     'end': 211},
#    {'tag': 'EMAIL',
#     'value': 'lincolnbaxter@gmail.com',
#     'start': 37,
#     'end': 60},
#    {'tag': 'IP_ADDRESS', 'value': '1.0.0.0', 'start': 666, 'end': 673},
#    {'tag': 'IP_ADDRESS', 'value': '1.0.0.0', 'start': 981, 'end': 988}]}]

# %% [markdown]
# #### Gibberish detector
# Adding the gibberish detector removes 173 false positives like:
# * ar/www/rajkdjango2/bin/python, param_and_buffer_names_set:, Msf::Exploit::Remote::SNMPClient, d2/d24/interfaceZeebe_1_1Client_1_1Api_1_1Builder_1_1IAccessTokenSupplier
#
# But also removes 8 hashes like these from files 31, 37:
# * d3d43ab4e03fdf106b9191f4e0161cfcde3f040e, d3d43ab4e03fdf106b9191f4e0161cfcde3f040e 8d11fab63089a24c8b17063d29a4b0eac359fb41
#
# Strings like this e2e_faster_rcnn_R-101-FPN_1x are considered gibberrish and thus detected as keys

# %%
from gibberish_detector import detector
Detector = detector.create_from_model('gibberish_data/big.model')
Detector.is_gibberish("e2e_faster_rcnn_R-101-FPN_1x".replace("_", " ").replace("-", " ").lower())
# Out:
# True

# %% [markdown]
# ### Email detection
#
# * our current regex detects many false positives taht are derivatives of: dusk-network/helpers@4.6.12
# * bigscience updated regex: can't detect emails well when they are in this format: <email> and also labels dusk-network/helpers@4.6.12 as emails, see https://regex101.com/r/LNwpG1/1

# %%
from detect_pii import scan_pii_batch_viz

examples = ds_full.select(range(100))
# to use  updated BigScience regex set new_email_regex=True
outputs = scan_pii_batch_viz(examples, key_detector="regex", new_email_regex=True)
# Out:
# context e2e_faster_rcnn_X-101-32x8d-FPN_1x: : "01_33_49.iAX0mXvW",
#         "35857345/e2e_faster_rcnn_R-50-FPN_1x": "01_36_30.cUF7QR7I",
#         "35857890/e2e_faster_rcnn_R-101-FPN_1x": "01_38_50.sNxI7sX7",
#         "36761737/e2e_faster_rcnn_X-101-32x8d-FPN_1x": "06_31_39.5MIHi1fZ",
#         "35858791/e2e_mask_rcnn_R-50-C4_1x": "01_45_57.ZgkA7hPB",
#         "35858933/e2e_mask_rcnn_R-50-FPN_1x": "01_48_14.DzEQe4wC",
#         "35861795/e2e_m
# True
# context e2e_keypoint_rcnn_R-50-FPN_1x: 843/e2e_mask_rcnn_X-101-32x8d-FPN_1x": "06_35_59.RZotkLKI",
#         "37129812/e2e_mask_rcnn_X-152-32x8d-FPN-IN5k_1.44x": "09_35_36.8pzTQKYK",
#         # keypoints
#         "37697547/e2e_keypoint_rcnn_R-50-FPN_1x": "08_42_54.kdzV35ao"
#     }
#
#     @staticmethod
#     def get(name):
#         if name.startswith("Caffe2Detectron/COCO"):
#             return ModelCatalog.get_c2_detectron_12_2017_base
# True

# %% [markdown]
# Let's test the recall of emails

# %%
from datasets import load_dataset

# this dataset has lists of PII without context
ds = load_dataset("loubnabnl/pii-instances", use_auth_token=True, split="train")
# Out:
# Using custom data configuration loubnabnl--pii-instances-b56ea5fc2b13487c
# Found cached dataset parquet (/Users/loubnabenallal/.cache/huggingface/datasets/loubnabnl___parquet/loubnabnl--pii-instances-b56ea5fc2b13487c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
# filter samples from ds with an empty email column
ds_emails = ds.filter(lambda x: x["EMAIL"] != "")["EMAIL"]
print(len(ds_emails))
# Out:
# Loading cached processed dataset at /Users/loubnabenallal/.cache/huggingface/datasets/loubnabnl___parquet/loubnabnl--pii-instances-b56ea5fc2b13487c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-05bc1724d8ac05a9.arrow
# 189

# %%
# sample 44 is a wrong annotation
ds_emails = ds_emails[:44] + ds_emails[45:]

# %%
# fiw an issue with this annotation
ds_emails[142] = ds_emails[142][:-1]
ds_emails[108] = ds_emails[108].strip()

# %%
ds_emails = list(set(ds_emails))
len(ds_emails)
# Out:
# 170

# %%
from utils.emails_ip_addresses_detection import detect_email_addresses

old_regex_results = []
new_regex_results = []
new_regex_nb = 0
old_regex_nb = 0
for key in ds_emails:
    output_1 = detect_email_addresses(key, tag_types={"EMAIL"}, new_email_regex=False)
    output_2 = detect_email_addresses(key, tag_types={"EMAIL"}, new_email_regex=True)
    if output_1:
        old_regex_nb += 1
        old_regex_results.append(output_1)
    if output_2:
        new_regex_nb += 1
        new_regex_results.append(output_2)

# %%
print(f"nb emails dectected by old regex: {old_regex_nb}")
print(f"nb emails dectected by new BS regex: {new_regex_nb}")
print(f"number true EMAILS: {len(ds_emails)}")
# Out:
# nb emails dectected by old regex: 170
# nb emails dectected by new BS regex: 169
# number true EMAILS: 170

# %%
def get_nb_detections(results, refs, mode="old"):
    res = 0
    values = []
    for i, elem in enumerate(results):
        assert len(elem) == 1
        value = elem[0]["value"]
        if value in refs:
            res += 1
            values.append(value)
        else:
            print(f"\nwrong detection of {mode} regex at {i} for {value}\n")
    return res, values

res, values = get_nb_detections(old_regex_results, ds_emails)
res_new, values_new = get_nb_detections(new_regex_results, ds_emails, mode="new")
print(f"number of correctly detected strings with old regex: {res}")
print(f"number of correctly detected strings with new regex: {res_new}")
# Out:
# number of correctly detected strings with old regex: 170
# number of correctly detected strings with new regex: 169

# %%
print("missed emails with the new regex")
# three of them were just truncated because they contained dots inside: not sure they are real keys
for key in ds_emails:
    if key not in values_new:
        print(key)
# Out:
# missed emails with the new regex
# noreply@127.0.0.1

# %% [markdown]
# It's a false annotation

# %%
for i in range(5):
    ds_emails[i] = "<" + ds_emails[i] + ">"
ds_emails[:7]
# Out:
# ['<loffjh@gmail.com>',
#  '<Chris.Mears@monash.edu>',
#  '<pychuang@gwu.edu>',
#  '<nguyenthieu2102@gmail.com>',
#  '<robert.kausch@gmx.net>',
#  'info@srampos.com',
#  'mark.samman@gmail.com']

# %%
from utils.emails_ip_addresses_detection import detect_email_addresses

old_regex_results = []
new_regex_results = []
new_regex_nb = 0
old_regex_nb = 0
for key in ds_emails[:7]:
    output_1 = detect_email_addresses(key, tag_types={"EMAIL"}, new_email_regex=False)
    output_2 = detect_email_addresses(key, tag_types={"EMAIL"}, new_email_regex=True)
    if output_1:
        old_regex_nb += 1
        old_regex_results.append(output_1)
    if output_2:
        new_regex_nb += 1
        new_regex_results.append(output_2)

print(f"nb emails dectected by old regex: {old_regex_nb}")
print(f"nb emails dectected by new BS regex: {new_regex_nb}")
print(f"number true EMAILS: {len(ds_emails[:7])}")
# Out:
# nb emails dectected by old regex: 7
# nb emails dectected by new BS regex: 2
# number true EMAILS: 7
